# %%
# !pip install nltk
# Out:
# Requirement already satisfied: nltk in c:\programdata\anaconda3\lib\site-packages (3.6.1)
# Requirement already satisfied: regex in c:\programdata\anaconda3\lib\site-packages (from nltk) (2021.4.4)
# Requirement already satisfied: click in c:\programdata\anaconda3\lib\site-packages (from nltk) (7.1.2)
# Requirement already satisfied: joblib in c:\programdata\anaconda3\lib\site-packages (from nltk) (1.0.1)
# Requirement already satisfied: tqdm in c:\programdata\anaconda3\lib\site-packages (from nltk) (4.59.0)

# %%
# !pip install zeyrek
# Out:
# Requirement already satisfied: zeyrek in c:\programdata\anaconda3\lib\site-packages (0.1.2)
# Requirement already satisfied: nltk>=3 in c:\programdata\anaconda3\lib\site-packages (from zeyrek) (3.6.1)
# Requirement already satisfied: joblib in c:\programdata\anaconda3\lib\site-packages (from nltk>=3->zeyrek) (1.0.1)
# Requirement already satisfied: tqdm in c:\programdata\anaconda3\lib\site-packages (from nltk>=3->zeyrek) (4.59.0)
# Requirement already satisfied: regex in c:\programdata\anaconda3\lib\site-packages (from nltk>=3->zeyrek) (2021.4.4)
# Requirement already satisfied: click in c:\programdata\anaconda3\lib\site-packages (from nltk>=3->zeyrek) (7.1.2)

# %%
# !pip install TurkishStemmer
# Out:
# Requirement already satisfied: TurkishStemmer in c:\programdata\anaconda3\lib\site-packages (1.3)

# %%
import nltk
import zeyrek # https://github.com/obulat/zeyrek
from TurkishStemmer import TurkishStemmer # https://github.com/otuncelli/turkish-stemmer-python

# %%
nltk.download("punkt")
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\Mustafa\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
analyzer = zeyrek.MorphAnalyzer()

# %%
analyzer.lemmatize("benimkilerden")
# Out:
# [('benimkilerden', ['benimki'])]

# %%
stemmer = TurkishStemmer()

# %%
stemmer.stem("benimkilerden")
# Out:
# 'benimki'

# %%
cumle = "Dönülmez akşamın ufkundayım."

# %%
stemmer.stem(cumle)
# Out:
# 'Dönülmez akşamın ufkundayım.'

# %%
analyzer.lemmatize(cumle)
# Out:
# [('Dönülmez', ['dönmek']),
#  ('akşamın', ['akşam']),
#  ('ufkundayım', ['ufuk']),
#  ('.', ['.'])]

# %%
for kelime in cumle.split():
    print(stemmer.stem(kelime))
# Out:
# Dönülmez
# akşa
# ufkundayım.

# %%
import pandas as pd

# %%
# !pip install openpyxl
# Out:
# Requirement already satisfied: openpyxl in c:\programdata\anaconda3\lib\site-packages (3.0.7)
# Requirement already satisfied: et-xmlfile in c:\programdata\anaconda3\lib\site-packages (from openpyxl) (1.0.1)

# %%
df = pd.read_excel("filmveriseti.xlsx") 
# https://www.kaggle.com/code/furkanyeter/content-based-recommendation-system-turkish-movie/data
df.head()
# Out:
#                                       film adi  \
# 0                                       Bergen
# 1                                Kirpi Sonic 2
# 2  Fantastik Canavarlar: Dumbledore'un Sırları
# 3                               Aykut Enişte 2
# 4                                      Morbius
#
#                                     ozet ve detaylar  \
# 0  Arabeskin unutulmayan kadın seslerinden biri o...
# 1  Çocuk filmi \n\n\nKirpi Sonic filminin devam h...
# 2  Karanlık büyücü Gellert Grindelwald, büyücülük...
# 3  Aykut Enişte 2, sevdiği kadınla evlilik arifes...
# 4  Morbius, hastalığına deva bulmaya çalışırken b...
#
#                                   tur  \
# 0              ['Dram', 'Biyografik']
# 1     ['Animasyon', 'Aile', 'Macera']
# 2             ['Fantastik', 'Macera']
# 3                          ['Komedi']
# 4  ['Aksiyon', 'Fantastik', 'Macera']
#
#                                            oyuncular  \
# 0  ['Farah Zeynep Abdullah', 'Erdal Beşikçioğlu',...
# 1              ['Jim Carrey', 'James Marsden', None]
# 2   ['Eddie Redmayne', 'Jude Law', 'Mads Mikkelsen']
# 3  ['Cem Gelinoğlu', 'Melis Babadağ', 'Hakan Yılm...
# 4  ['Jared Leto', 'Matt Smith (XI)', 'Adria Arjona']
#
#                           yonetmen  vizyon tarihi     sure
# 0  ['Mehmet Binay', 'Caner Alper']    4 Mart 2022  2s 26dk
# 1                  ['Jeff Fowler']   8 Nisan 2022   2s 2dk
# 2                  ['David Yates']  15 Nisan 2022  2s 22dk
# 3                ['Onur Bilgetay']  3 Aralık 2021  1s 55dk
# 4              ['Daniel Espinosa']   1 Nisan 2022  1s 45dk

# %%
len(df)
# Out:
# 5261

# %%
df["tur"].unique()
# Out:
# array(["['Dram', 'Biyografik']", "['Animasyon', 'Aile', 'Macera']",
#        "['Fantastik', 'Macera']", "['Komedi']",
#        "['Aksiyon', 'Fantastik', 'Macera']",
#        "['Animasyon', 'Aile', 'Komedi']", "['Dram']",
#        "['Dram', 'Aksiyon']", "['Aksiyon', 'Macera', 'Fantastik']",
#        "['Aksiyon', 'Polisiye', 'Gerilim']",
#        "['Fantastik', 'Aksiyon', 'Macera']", "['Biyografik', 'Dram']",
#        "['Animasyon']", "['Bilimkurgu', 'Gerilim', 'Aksiyon']",
#        "['Dram', 'Romantik', 'Gerilim']",
#        "['Romantik', 'Dram', 'Erotik']",
#        "['Komedi', 'Aksiyon', 'Macera']", "['Macera', 'Aile']",
#        "['Aksiyon', 'Tarihi']", "['Bilimkurgu', 'Dram']", "['Aksiyon']",
#        "['Aksiyon', 'Fantastik']", "['Gerilim', 'Korku']",
#        "['Komedi', 'Romantik']", "['Dram', 'Romantik']",
#        "['Bilimkurgu', 'Gerilim']", "['Animasyon', 'Macera', 'Komedi']",
#        "['Komedi', 'Aksiyon', 'Bilimkurgu']",
#        "['Romantik', 'Fantastik', 'Dram']", "['Dram', 'Erotik']",
#        "['Gerilim', 'Dram']", "['Aksiyon', 'Gerilim']",
#        "['Fantastik', 'Macera', 'Aile']", "['Animasyon', 'Aile']",
#        "['Macera', 'Aksiyon']", "['Korku']", "['Gerilim']",
#        "['Macera', 'Aksiyon', 'Fantastik']",
#        "['Komedi', 'Fantastik', 'Aile', 'Macera']", "['Aile', 'Komedi']",
#        "['Animasyon', 'Aile', 'Fantastik', 'Komedi']",
#        "['Komedi', 'Dram']", "['Dram', 'Romantik', 'Erotik']",
#        "['Tarihi']", "['Animasyon', 'Komedi', 'Aile', 'Macera']",
#        "['Polisiye', 'Dram']", "['Animasyon', 'Macera']",
#        "['Dram', 'Gerilim']", "['Aksiyon', 'Polisiye']",
#        "['Romantik', 'Komedi']", "['Aksiyon', 'Dram', 'Biyografik']",
#        "['Dram', 'Tarihi']", "['Bilimkurgu', 'Korku', 'Gerilim']",
#        "['Gerilim', 'Fantastik']", "['Romantik', 'Dram']",
#        "['Gerilim', 'Aksiyon']", "['Aksiyon', 'Macera']", "['Erotik']",
#        "['Fantastik', 'Romantik']", "['Macera', 'Aile', 'Fantastik']",
#        "['Korku', 'Gerilim']", "['Bilimkurgu', 'Aksiyon']",
#        "['Polisiye', 'Dram', 'Komedi']", "['Dram', 'Komedi']",
#        "['Dramatik komedi']", "['Dram', 'Müzik']",
#        "['Aksiyon', 'Bilimkurgu']", "['Savaş filmi', 'Dram']",
#        "['Erotik', 'Dram', 'Romantik']",
#        "['Bilimkurgu', 'Romantik', 'Aksiyon']", "['Komedi', 'Aile']",
#        "['Komedi', 'Romantik', 'Erotik']",
#        "['Animasyon', 'Komedi', 'Aile']",
#        "['Animasyon', 'Fantastik', 'Aile']", "['Tarihi', 'Aksiyon']",
#        "['Aksiyon', 'Macera', 'Bilimkurgu']",
#        "['Gerilim', 'Polisiye', 'Dram']",
#        "['Bilimkurgu', 'Dram', 'Komedi']",
#        "['Animasyon', 'Aksiyon', 'Komedi', 'Aile']",
#        "['Aksiyon', 'Korku']", "['Gerilim', 'Polisiye', 'Erotik']",
#        "['Aksiyon', 'Macera', 'Dram', 'Tarihi', 'Savaş filmi']",
#        "['Savaş filmi', 'Dram', 'Aksiyon']",
#        "['Animasyon', 'Aile', 'Fantastik']", "['Aile']",
#        "['Fantastik', 'Aksiyon']",
#        "['Animasyon', 'Komedi', 'Macera', 'Aile']",
#        "['Gerilim', 'Dram', 'Aksiyon']", "['Aksiyon', 'Casusluk']",
#        "['Dram', 'Savaş filmi']",
#        "['Macera', 'Animasyon', 'Aile', 'Aksiyon', 'Komedi']",
#        "['Fantastik']", "['Fantastik', 'Aile']",
#        "['Fantastik', 'Aksiyon', 'Gerilim']", "['Dram', 'Aile']",
#        "['Komedi', 'Animasyon']",
#        "['Animasyon', 'Macera', 'Fantastik', 'Aile']",
#        "['Bilimkurgu', 'Macera']",
#        "['Bilimkurgu', 'Aksiyon', 'Fantastik']",
#        "['Animasyon', 'Aksiyon', 'Fantastik']",
#        "['Gerilim', 'Romantik', 'Dram']", "['Komedi', 'Dram', 'Aile']",
#        "['Bilimkurgu']", "['Fantastik', 'Polisiye']",
#        "['Dram', 'Macera', 'Romantik']",
#        "['Animasyon', 'Fantastik', 'Aile', 'Romantik', 'Müzikal']",
#        "['Aksiyon', 'Dram']", "['Dram', 'Macera']",
#        "['Dram', 'Bollywood']", "['Macera', 'Fantastik']",
#        "['Dram', 'Fantastik', 'Romantik']", "['Animasyon', 'Müzik']",
#        "['Gerilim', 'Dram', 'Korku']", "['Bollywood', 'Dram']",
#        "['Fantastik', 'Romantik', 'Macera', 'Dram']",
#        "['Komedi', 'Bollywood']", "['Dram', 'Biyografik', 'Komedi']",
#        "['Romantik', 'Dram', 'Komedi']",
#        "['Aksiyon', 'Gerilim', 'Casusluk']",
#        "['Macera', 'Aksiyon', 'Dram']",
#        "['Macera', 'Fantastik', 'Dram', 'Epik']",
#        "['Gerilim', 'Polisiye', 'Aksiyon']",
#        "['Bilimkurgu', 'Fantastik', 'Aksiyon']",
#        "['Dram', 'Gerilim', 'Erotik']",
#        "['Dram', 'Gerilim', 'Fantastik']", "['Western', 'Macera']",
#        "['Animasyon', 'Müzikal', 'Aile']",
#        "['Romantik', 'Fantastik', 'Macera']",
#        "['Tarihi', 'Dram', 'Savaş filmi', 'Aksiyon']",
#        "['Gerilim', 'Fantastik', 'Korku']", "['Dram', 'Bilimkurgu']",
#        "['Aksiyon', 'Gerilim', 'Bilimkurgu']",
#        "['Tarihi', 'Savaş filmi']", "['Dram', 'Polisiye']",
#        "['Animasyon', 'Macera', 'Bilimkurgu', 'Fantastik']",
#        "['Aksiyon', 'Dövüş', 'Dram', 'Biyografik']", "['Romantik']",
#        "['Macera', 'Dram']", "['Polisiye']",
#        "['Tarihi', 'Biyografik', 'Dram']",
#        "['Dramatik komedi', 'Komedi', 'Romantik']",
#        "['Bilimkurgu', 'Aksiyon', 'Gerilim']", "['Bilimkurgu', 'Komedi']",
#        "['Polisiye', 'Gerilim']",
#        "['Epik', 'Aksiyon', 'Savaş filmi', 'Tarihi']",
#        "['Animasyon', 'Aksiyon', 'Aile']", "['Polisiye', 'Komedi']",
#        "['Macera', 'Komedi']", "['Fantastik', 'Korku', 'Gerilim']",
#        "['Aksiyon', 'Casusluk', 'Komedi']",
#        "['Aksiyon', 'Savaş filmi', 'Dram']",
#        "['Komedi', 'Aksiyon', 'Fantastik']",
#        "['Gerilim', 'Korku', 'Fantastik']", "['Biyografik']",
#        "['Animasyon', 'Komedi']", "['Dram', 'Gerilim', 'Biyografik']",
#        "['Macera', 'Komedi', 'Fantastik']", "['Komedi', 'Aksiyon']",
#        "['Komedi', 'Fantastik', 'Dram']",
#        "['Dram', 'Bilimkurgu', 'Gerilim']", "['Macera', 'Dram', 'Aile']",
#        "['Western']", "['Aksiyon', 'Bilimkurgu', 'Gerilim']",
#        "['Aksiyon', 'Korku', 'Gerilim']",
#        "['Dram', 'Komedi', 'Romantik']",
#        "['Fantastik', 'Dram', 'Romantik']", "['Polisiye', 'Aksiyon']",
#        "['Dram', 'Gerilim', 'Macera', 'Biyografik']",
#        "['Aksiyon', 'Casusluk', 'Macera']", "['Komedi', 'Macera']",
#        "['Dram', 'Fantastik']", "['Aksiyon', 'Gerilim', 'Korku']",
#        "['Fantastik', 'Dram', 'Korku']",
#        "['Korku', 'Aksiyon', 'Gerilim']",
#        "['Aksiyon', 'Gerilim', 'Dram']",
#        "['Savaş filmi', 'Dram', 'Biyografik']",
#        "['Dram', 'Macera', 'Tarihi']", "['Animasyon', 'Macera', 'Aile']",
#        "['Gerilim', 'Romantik', 'Komedi']",
#        "['Fantastik', 'Aksiyon', 'Macera', 'Tarihi']",
#        "['Fantastik', 'Epik', 'Macera']", "['Gerilim', 'Biyografik']",
#        "['Fantastik', 'Bilimkurgu']",
#        "['Animasyon', 'Macera', 'Aile', 'Komedi']",
#        "['Bilimkurgu', 'Aksiyon', 'Romantik']", "['Erotik', 'Dram']",
#        "['Aksiyon', 'Korku', 'Bilimkurgu']",
#        "['Komedi', 'Aile', 'Fantastik']",
#        "['Fantastik', 'Romantik', 'Müzikal']",
#        "['Tarihi', 'Biyografik ', 'Savaş filmi', 'Romantik']",
#        "['Animasyon', 'Fantastik']", "['Biyografik', 'Müzik', 'Dram']",
#        "['Dramatik komedi', 'Müzik']", "['Macera', 'Bilimkurgu']",
#        "['Dram', 'Casusluk', 'Gerilim', 'Biyografik']",
#        "['Bilimkurgu', 'Aksiyon', 'Macera']",
#        "['Macera', 'Animasyon', 'Aile']",
#        "['Animasyon', 'Komedi', 'Aile', 'Fantastik']",
#        "['Dram', 'Tarihi', 'Biyografik']", "['Fantastik', 'Gerilim']",
#        "['Bilimkurgu', 'Bollywood']", "['Savaş filmi', 'Aksiyon']",
#        "['Komedi', 'Romantik', 'Fantastik']",
#        "['Bilimkurgu', 'Aksiyon', 'Dram']",
#        "['Dramatik komedi', 'Fantastik']",
#        "['Fantastik', 'Macera', 'Dram', 'Aile']", "['Tarihi', 'Dram']",
#        "['Komedi', 'Dram', 'Romantik']", "['Aksiyon', 'Dram', 'Gerilim']",
#        "['Korku', 'Komedi']", "['Gerilim', 'Romantik']",
#        "['Fantastik', 'Macera', 'Aksiyon']",
#        "['Macera', 'Dram', 'Biyografik']",
#        "['Macera', 'Dram', 'Gerilim']",
#        "['Animasyon', 'Komedi', 'Macera']", "['Biyografik', 'Bollywood']",
#        "['Bilimkurgu', 'Fantastik', 'Korku']",
#        "['Aksiyon', 'Fantastik', 'Epik']",
#        "['Gerilim', 'Aksiyon', 'Polisiye']", "['Fantastik', 'Korku']",
#        "['Macera', 'Bilimkurgu', 'Aksiyon']",
#        "['Animasyon', 'Komedi', 'Aksiyon']", "['Dövüş', 'Aksiyon']",
#        "['Dramatik komedi', 'Mahkeme']",
#        "['Aksiyon', 'Dram', 'Bilimkurgu']", "['Komedi', 'Polisiye']",
#        "['Macera', 'Aksiyon', 'Bilimkurgu']", "['Gerilim', 'Bilimkurgu']",
#        "['Fantastik', 'Macera', 'Korku']",
#        "['Macera', 'Fantastik', 'Aksiyon']", "['Gerilim', 'Casusluk']",
#        "['Korku', 'Fantastik', 'Bilimkurgu', 'Gerilim', 'Aksiyon']",
#        "['Bilimkurgu', 'Dram', 'Romantik']",
#        "['Dram', 'Tarihi', 'Savaş filmi']", "['Gerilim', 'Polisiye']",
#        "['Dram', 'Tarihi', 'Romantik']", "['Macera', 'Animasyon']",
#        "['Macera']", "['Animasyon', 'Aile', 'Macera', 'Bilimkurgu']",
#        "['Fantastik', 'Bilimkurgu', 'Aksiyon']",
#        "['Gerilim', 'Dram', 'Western']",
#        "['Dramatik komedi', 'Romantik']",
#        "['Dram', 'Romantik', 'Bilimkurgu']", "['Gerilim', 'Savaş filmi']",
#        "['Aksiyon', 'Komedi']", "['Biyografik', 'Savaş filmi', 'Dram']",
#        "['Bilimkurgu', 'Romantik', 'Gerilim']",
#        "['Animasyon', 'Aksiyon']",
#        "['Savaş filmi', 'Biyografik ', 'Dram']",
#        "['Dram', 'Savaş filmi', 'Gerilim']",
#        "['Gerilim', 'Bilimkurgu', 'Korku']",
#        "['Animasyon', 'Komedi', 'Fantastik', 'Aile']",
#        "['Fantastik', 'Bilimkurgu', 'Dram']",
#        "['Epik', 'Aksiyon', 'Macera']",
#        "['Gerilim', 'Savaş filmi', 'Dram']",
#        "['Dram', 'Mahkeme', 'Gerilim']",
#        "['Gerilim', 'Dram', 'Polisiye']",
#        "['Dram', 'Korku', 'Bilimkurgu']",
#        "['Bilimkurgu', 'Macera', 'Aksiyon', 'Fantastik']",
#        "['Biyografik', 'Dram', 'Tarihi']",
#        "['Komedi', 'Aile', 'Romantik']",
#        "['Bilimkurgu', 'Gerilim', 'Dram']",
#        "['Dram', 'Macera', 'Komedi']",
#        "['Savaş filmi', 'Gerilim', 'Dram']",
#        "['Savaş filmi', 'Tarihi', 'Dram']",
#        "['Animasyon', 'Macera', 'Müzik']",
#        "['Aksiyon', 'Fantastik', 'Bilimkurgu']",
#        "['Romantik', 'Komedi', 'Fantastik']",
#        "['Komedi', 'Fantastik', 'Aile']",
#        "['Aksiyon', 'Fantastik', 'Gerilim']",
#        "['Dramatik komedi', 'Tarihi']", "['Aksiyon', 'Dram', 'Romantik']",
#        "['Macera', 'Fantastik', 'Bilimkurgu']",
#        "['Macera', 'Bilimkurgu', 'Gerilim']", "['Müzikal', 'Romantik']",
#        "['Komedi', 'Animasyon', 'Aile']",
#        "['Biyografik', 'Tarihi', 'Dram']",
#        "['Gerilim', 'Aksiyon', 'Dram']",
#        "['Dramatik komedi', 'Biyografik']", "['Aksiyon', 'Savaş filmi']",
#        "['Dram', 'Polisiye', 'Gerilim']",
#        "['Animasyon', 'Fantastik', 'Komedi']",
#        "['Animasyon', 'Aksiyon', 'Komedi', 'Aile', 'Macera']",
#        "['Aksiyon', 'Bollywood']", "['Polisiye', 'Aksiyon', 'Dram']",
#        "['Korku', 'Gerilim', 'Bilimkurgu']",
#        "['Animasyon', 'Aile', 'Macera', 'Komedi']", "['Savaş filmi']",
#        "['Komedi', 'Macera', 'Dram']", "['Komedi', 'Fantastik']",
#        "['Aksiyon', 'Macera', 'Gerilim', 'Bilimkurgu']",
#        "['Romantik', 'Dram', 'Fantastik']",
#        "['Macera', 'Fantastik', 'Aile']",
#        "['Fantastik', 'Dram', 'Bilimkurgu']", "['Gerilim', 'Macera']",
#        "['Animasyon', 'Macera', 'Komedi', 'Aile']",
#        "['Aksiyon', 'Bilimkurgu', 'Macera']",
#        "['Macera', 'Aksiyon', 'Aile', 'Fantastik']",
#        "['Bilimkurgu', 'Korku']", "['Dram', 'Komedi', 'Biyografik']",
#        "['Aile', 'Fantastik']",
#        "['Bilimkurgu', 'Romantik', 'Fantastik', 'Dram']",
#        "['Dövüş', 'Aksiyon', 'Dram', 'Aile']", "['Fantastik', 'Komedi']",
#        "['Macera', 'Dram', 'Tarihi']",
#        "['Aksiyon', 'Komedi', 'Fantastik']",
#        "['Bilimkurgu', 'Korku', 'Aksiyon']",
#        "['Tarihi', 'Macera', 'Savaş filmi']",
#        "['Bilimkurgu', 'Macera', 'Dram']",
#        "['Aksiyon', 'Macera', 'Dram']", "['Macera', 'Aksiyon', 'Komedi']",
#        "['Gerilim', 'Aksiyon', 'Komedi']",
#        "['Dram', 'Savaş filmi', 'Gerilim', 'Aksiyon']",
#        "['Polisiye', 'Bilimkurgu', 'Aksiyon']",
#        "['Gerilim', 'Dram', 'Tarihi']",
#        "['Western', 'Aksiyon', 'Macera']",
#        "['Korku', 'Fantastik', 'Gerilim']",
#        "['Aksiyon', 'Fantastik', 'Korku']",
#        "['Aksiyon', 'Macera', 'Bilimkurgu', 'Gerilim']",
#        "['Aksiyon', 'Gerilim', 'Polisiye']", "['Western', 'Aksiyon']",
#        "['Gerilim', 'Aksiyon', 'Mahkeme']",
#        "['Dramatik komedi', 'Gerilim']",
#        "['Animasyon', 'Macera', 'Fantastik', 'Komedi']",
#        "['Müzikal', 'Romantik', 'Dram']",
#        "['Bilimkurgu', 'Macera', 'Aksiyon']", "['Biyografik', 'Gerilim']",
#        "['Korku', 'Dram']", "['Dram', 'Polisiye', 'Romantik', 'Gerilim']",
#        "['Animasyon', 'Komedi', 'Aksiyon', 'Fantastik']",
#        "['Fantastik', 'Macera', 'Dram']",
#        "['Bilimkurgu', 'Fantastik', 'Dram']",
#        "['Aksiyon', 'Macera', 'Dövüş', 'Gerilim']", "['Korku', 'Macera']",
#        "['Tarihi', 'Gerilim', 'Savaş filmi']", "['Komedi', 'Korku']",
#        "['Dram', 'Aksiyon', 'Gerilim']",
#        "['Macera', 'Dram', 'Fantastik']",
#        "['Savaş filmi', 'Aksiyon', 'Romantik']",
#        "['Aksiyon', 'Macera', 'Fantastik', 'Bilimkurgu']",
#        "['Aksiyon', 'Macera', 'Bilimkurgu', 'Fantastik']",
#        "['Dram', 'Gerilim', 'Tarihi']",
#        "['Fantastik', 'Gerilim', 'Dram']",
#        "['Bilimkurgu', 'Gerilim', 'Macera']", "['Western', 'Korku']",
#        "['Korku', 'Gerilim', 'Fantastik', 'Bilimkurgu']",
#        "['Fantastik', 'Aksiyon', 'Korku']",
#        "['Dramatik komedi', 'Aile', 'Romantik']",
#        "['Dram', 'Romantik', 'Biyografik']",
#        "['Korku', 'Gerilim', 'Dram']", "['Macera', 'Biyografik']",
#        "['Müzikal', 'Gerilim', 'Korku', 'Dram']",
#        "['Müzikal', 'Dram', 'Polisiye']",
#        "['Fantastik', 'Macera', 'Dram', 'Bilimkurgu', 'Aksiyon']",
#        "['Gerilim', 'Dram', 'Bilimkurgu']",
#        "['Korku', 'Gerilim', 'Fantastik']",
#        "['Aksiyon', 'Macera', 'Gerilim']",
#        "['Dram', 'Romantik', 'Fantastik']",
#        "['Gerilim', 'Aksiyon', 'Korku']",
#        "['Bilimkurgu', 'Aile', 'Macera']",
#        "['Fantastik', 'Gerilim', 'Bilimkurgu']",
#        "['Macera', 'Aksiyon', 'Polisiye']",
#        "['Mahkeme', 'Gerilim', 'Komedi']", "['Aile', 'Macera', 'Komedi']",
#        "['Komedi', 'Macera', 'Aile']", "['Aile', 'Macera']",
#        "['Macera', 'Komedi', 'Bilimkurgu']",
#        "['Romantik', 'Dramatik komedi']",
#        "['Macera', 'Aksiyon', 'Romantik']",
#        "['Polisiye', 'Dram', 'Gerilim']", "['Dram', 'Aksiyon', 'Tarihi']",
#        "['Polisiye', 'Biyografik', 'Dram']",
#        "['Komedi', 'Romantik', 'Korku']",
#        "['Aksiyon', 'Gerilim', 'Romantik']",
#        "['Biyografik', 'Mahkeme', 'Dram', 'Macera']",
#        "['Aksiyon', 'Komedi', 'Casusluk', 'Romantik']",
#        "['Fantastik', 'Dram']", "['Macera', 'Aile', 'Bilimkurgu']",
#        "['Aksiyon', 'Gerilim', 'Macera']", "['Animasyon', 'Biyografik']",
#        "['Animasyon', 'Aile', 'Müzikal']",
#        "['Fantastik', 'Macera', 'Bilimkurgu', 'Aksiyon']",
#        "['Biyografik', 'Romantik']", "['Macera', 'Aksiyon', 'Epik']",
#        "['Animasyon', 'Komedi', 'Müzik']",
#        "['Animasyon', 'Aile', 'Romantik', 'Müzik']",
#        "['Bilimkurgu', 'Korku', 'Dram']",
#        "['Aksiyon', 'Komedi', 'Macera']",
#        "['Dram', 'Biyografik ', 'Romantik']",
#        "['Dram', 'Biyografik', 'Tarihi']",
#        "['Animasyon', 'Macera', 'Komedi', 'Aile', 'Fantastik']",
#        "['Macera', 'Bilimkurgu', 'Savaş filmi']",
#        "['Savaş filmi', 'Romantik']",
#        "['Fantastik', 'Bilimkurgu', 'Gerilim', 'Aksiyon']",
#        "['Korku', 'Dram', 'Gerilim']", "['Komedi', 'Erotik']",
#        "['Polisiye', 'Gerilim', 'Aksiyon']",
#        "['Korku', 'Dram', 'Fantastik']", "['Polisiye', 'Biyografik']",
#        "['Aksiyon', 'Gerilim', 'Polisiye', 'Macera']",
#        "['Korku', 'Fantastik']", "['Aksiyon', 'Macera', 'Komedi']",
#        "['Biyografik', 'Tarihi']", "['Komedi', 'Dram', 'Fantastik']",
#        "['Dram', 'Romantik', 'Müzikal']",
#        "['Animasyon', 'Komedi', 'Fantastik']",
#        "['Komedi', 'Bilimkurgu', 'Aksiyon']", "['Macera', 'Gerilim']",
#        "['Komedi', 'Dram', 'Savaş filmi', 'Dramatik komedi']",
#        "['Dram', 'Aksiyon', 'Polisiye']",
#        "['Polisiye', 'Gerilim', 'Dram']",
#        "['Romantik', 'Komedi', 'Dram']", "['Korku', 'Bilimkurgu']",
#        "['Animasyon', 'Aile', 'Komedi', 'Fantastik']",
#        "['Aksiyon', 'Bilimkurgu', 'Komedi']",
#        "['Aksiyon', 'Dram', 'Savaş filmi']",
#        "['Tarihi', 'Dram', 'Romantik']",
#        "['Fantastik', 'Komedi', 'Korku']",
#        "['Komedi', 'Fantastik', 'Romantik']",
#        "['Macera', 'Dram', 'Gerilim', 'Polisiye']",
#        "['Tarihi', 'Dram', 'Macera']",
#        "['Bilimkurgu', 'Macera', 'Fantastik']", "['Casusluk', 'Gerilim']",
#        "['Dövüş', 'Aksiyon', 'Fantastik']",
#        "['Animasyon ', 'Komedi', 'Aile']",
#        "['Macera', 'Korku', 'Bilimkurgu']",
#        "['Dramatik komedi', 'Aksiyon']",
#        "['Korku', 'Aksiyon', 'Fantastik']",
#        "['Animasyon', 'Müzik', 'Aile']",
#        "['Gerilim', 'Dram', 'Polisiye', 'Biyografik']",
#        "['Gerilim', 'Korku', 'Dram']",
#        "['Bilimkurgu', 'Dram', 'Macera', 'Romantik']",
#        "['Gerilim', 'Macera', 'Korku']", "['Dram', 'Macera', 'Aile']",
#        "['Dram', 'Macera', 'Gerilim']", "['Casusluk', 'Aksiyon']",
#        "['Aksiyon', 'Dövüş', 'Biyografik']",
#        "['Dramatik komedi', 'Fantastik', 'Dram', 'Komedi']",
#        "['Fantastik', 'Romantik', 'Aksiyon']",
#        "['Macera', 'Aile', 'Dram']",
#        "['Dramatik komedi', 'Dram', 'Komedi']",
#        "['Savaş filmi', 'Romantik', 'Gerilim']",
#        "['Macera', 'Tarihi', 'Fantastik']",
#        "['Fantastik', 'Gerilim', 'Aksiyon']",
#        "['Macera', 'Komedi', 'Aksiyon']", "['Tarihi', 'Biyografik']",
#        "['Biyografik', 'Gerilim', 'Polisiye']",
#        "['Fantastik', 'Aksiyon', 'Bilimkurgu']",
#        "['Dram', 'Fantastik', 'Korku']", "['Komedi', 'Romantik', 'Dram']",
#        "['Polisiye', 'Korku']",
#        "['Animasyon', 'Dram', 'Tarihi', 'Biyografik']",
#        "['Tarihi', 'Gerilim']", "['Dram', 'Korku', 'Gerilim']",
#        "['Müzik', 'Dram']", "['Western', 'Dram']",
#        "['Dram', 'Müzik', 'Romantik']", "['Dram', 'Gerilim', 'Polisiye']",
#        "['Animasyon', 'Macera', 'Fantastik', 'Müzikal']",
#        "['Dram', 'Aksiyon', 'Western']",
#        "['Casusluk', 'Gerilim', 'Aksiyon']",
#        "['Aksiyon', 'Dram', 'Polisiye', 'Romantik']",
#        "['Savaş filmi', 'Aksiyon', 'Dram']",
#        "['Dram', 'Romantik', 'Macera']",
#        "['Romantik', 'Bilimkurgu', 'Dram']",
#        "['Casusluk', 'Aksiyon', 'Gerilim']", "['Polisiye', 'Romantik']",
#        "['Dram', 'Tarihi', 'Gerilim']", "['Dram', 'Romantik', 'Komedi']",
#        "['Bilimkurgu', 'Fantastik']", "['Polisiye', 'Dram', 'Aksiyon']",
#        "['Dramatik komedi', 'Müzik', 'Romantik']",
#        "['Fantastik', 'Komedi', 'Romantik']",
#        "['Western', 'Macera', 'Dram']", "['Aile', 'Komedi', 'Animasyon']",
#        "['Macera', 'Dram', 'Aksiyon']", "['Animasyon', 'Gerilim']",
#        "['Macera', 'Animasyon', 'Aksiyon', 'Aile']",
#        "['Gerilim', 'Romantik', 'Tarihi']", "['Aksiyon', 'Dövüş']",
#        "['Romantik', 'Bilimkurgu', 'Komedi', 'Dram']",
#        "['Dramatik komedi', 'Biyografik', 'Dram']",
#        "['Bollywood', 'Tarihi']",
#        "['Macera', 'Aksiyon', 'Korku', 'Gerilim']",
#        "['Fantastik', 'Macera', 'Komedi', 'Bilimkurgu']",
#        "['Dramatik komedi', 'Macera']",
#        "['Aksiyon', 'Komedi', 'Dram', 'Bilimkurgu']",
#        "['Dram', 'Aksiyon', 'Macera']", "['Tarihi', 'Epik']",
#        "['Animasyon ', 'Fantastik', 'Macera']",
#        "['Macera', 'Bilimkurgu', 'Dram']",
#        "['Western', 'Aksiyon', 'Gerilim', 'Polisiye']",
#        "['Animasyon', 'Dram', 'Aile']",
#        "['Fantastik', 'Dramatik komedi']",
#        "['Dram', 'Gerilim', 'Savaş filmi']",
#        "['Dramatik komedi', 'Dram', 'Aile']",
#        "['Animasyon', 'Macera', 'Aile', 'Fantastik']",
#        "['Animasyon', 'Fantastik', 'Macera', 'Aile']",
#        "['Dramatik komedi', 'Polisiye']",
#        "['Komedi', 'Korku', 'Aksiyon']", "['Gerilim', 'Tarihi', 'Dram']",
#        "['Korku', 'Fantastik', 'Dram']",
#        "['Gerilim', 'Erotik', 'Polisiye']", "['Bilimkurgu', 'Romantik']",
#        "['Aksiyon', 'Dram', 'Polisiye']",
#        "['Gerilim', 'Korku', 'Polisiye']", "['Biyografik ', 'Dram']",
#        "['Animasyon', 'Macera', 'Fantastik', 'Bilimkurgu']",
#        "['Dram', 'Biyografik', 'Romantik']",
#        "['Tarihi', 'Savaş filmi', 'Romantik', 'Biyografik']",
#        "['Fantastik', 'Animasyon', 'Müzikal']",
#        "['Komedi', 'Aksiyon', 'Romantik']", "['Komedi', 'Aile', 'Dram']",
#        "['Dramatik komedi', 'Bollywood']",
#        "['Tarihi', 'Aksiyon', 'Dram']", "['Aksiyon', 'Macera', 'Tarihi']",
#        "['Aksiyon', 'Casusluk', 'Gerilim']",
#        "['Biyografik', 'Savaş filmi']", "['Dram', 'Gerilim', 'Romantik']",
#        "['Bilimkurgu', 'Dram', 'Aksiyon']",
#        "['Polisiye', 'Dram', 'Romantik']",
#        "['Bilimkurgu', 'Macera', 'Komedi']",
#        "['Aksiyon', 'Bilimkurgu', 'Fantastik']",
#        "['Gerilim', 'Polisiye', 'Komedi']",
#        "['Korku', 'Bilimkurgu', 'Fantastik']",
#        "['Dram', 'Aile', 'Fantastik']",
#        "['Aksiyon', 'Macera', 'Polisiye']",
#        "['Tarihi', 'Dram', 'Gerilim']",
#        "['Dram', 'Savaş filmi', 'Romantik']",
#        "['Aksiyon', 'Macera', 'Fantastik', 'Gerilim']",
#        "['Dram', 'Mahkeme']", "['Korku', 'Macera', 'Dram', 'Gerilim']",
#        "['Animasyon', 'Dram', 'Savaş filmi']",
#        "['Aksiyon', 'Komedi', 'Polisiye']",
#        "['Bilimkurgu', 'Komedi', 'Macera']",
#        "['Korku', 'Dram', 'Romantik']",
#        "['Western', 'Biyografik', 'Dram']",
#        "['Romantik', 'Aile', 'Dram']", "['Animasyon ', 'Macera', 'Aile']",
#        "['Bilimkurgu', 'Korku', 'Aksiyon', 'Gerilim']",
#        "['Dram', 'Animasyon']", "['Dram', 'Müzikal']",
#        "['Aksiyon', 'Polisiye', 'Dram']",
#        "['Animasyon', 'Macera', 'Fantastik']",
#        "['Komedi', 'Polisiye', 'Romantik']", "['Aile', 'Dram']",
#        "['Bilimkurgu', 'Aksiyon', 'Korku']", "['Animasyon ', 'Aile']",
#        "['Experimental']", "['Komedi', 'Fantastik', 'Macera']",
#        "['Macera', 'Aksiyon', 'Tarihi']",
#        "['Komedi', 'Aile', 'Animasyon']", "['Dramatik komedi', 'Dram']",
#        "['Dram', 'Gerilim', 'Mahkeme']", "['Dram', 'Romantik', 'Müzik']",
#        "['Komedi', 'Polisiye', 'Aksiyon']", "['Aksiyon', 'Dram', 'Aile']",
#        "['Dövüş', 'Aksiyon', 'Dram']",
#        "['Korku', 'Bilimkurgu', 'Gerilim']",
#        "['Komedi', 'Aile', 'Macera']",
#        "['Gerilim', 'Fantastik', 'Polisiye']",
#        "['Aksiyon', 'Macera', 'Western']",
#        "['Macera', 'Dram', 'Polisiye']",
#        "['Dram', 'Savaş filmi', 'Tarihi', 'Romantik']",
#        "['Bilimkurgu', 'Gerilim', 'Fantastik']",
#        "['Aksiyon', 'Macera', 'Romantik']", "['Müzikal', 'Fantastik']",
#        "['Aksiyon', 'Komedi', 'Macera', 'Aile']",
#        "['Fantastik', 'Animasyon', 'Macera']",
#        "['Animasyon', 'Macera', 'Dram', 'Aile']",
#        "['Dram', 'Komedi', 'Polisiye']",
#        "['Komedi', 'Macera', 'Fantastik']",
#        "['Aksiyon', 'Dram', 'Komedi']",
#        "['Casusluk', 'Aksiyon', 'Komedi']",
#        "['Aksiyon', 'Macera', 'Biyografik']", "['Komedi', 'Müzikal']",
#        "['Polisiye', 'Dram', 'Korku']",
#        "['Animasyon', 'Fantastik', 'Macera']", "['Animasyon ', 'Dram']",
#        "['Bilimkurgu', 'Aksiyon', 'Komedi']",
#        "['Dram', 'Korku', 'Romantik']", "['Fantastik', 'Komedi', 'Dram']",
#        "['Fantastik', 'Dram', 'Gerilim']", "['Korku', 'Aksiyon']",
#        "['Animasyon', 'Macera', 'Dram']",
#        "['Fantastik', 'Müzikal', 'Macera']",
#        "['Macera', 'Tarihi', 'Romantik']",
#        "['Fantastik', 'Komedi', 'Aile']", "['Gerilim', 'Komedi']",
#        "['Komedi', 'Casusluk']", "['Dramatik komedi', 'Aile']",
#        "['Dram', 'Romantik', 'Gerilim', 'Erotik']",
#        "['Western', 'Macera', 'Komedi']",
#        "['Biyografik', 'Komedi', 'Dram']",
#        "['Korku', 'Gerilim', 'Aksiyon', 'Fantastik', 'Komedi']",
#        "['Bilimkurgu', 'Dram', 'Gerilim']", "['Müzik', 'Romantik']",
#        "['Macera', 'Korku', 'Gerilim']",
#        "['Aksiyon', 'Komedi', 'Macera', 'Polisiye']",
#        "['Tarihi', 'Polisiye']", "['Biyografik', 'Dram', 'Macera']",
#        "['Dram', 'Korku']", "['Gerilim', 'Dram', 'Erotik']",
#        "['Macera', 'Aksiyon', 'Fantastik', 'Gerilim']",
#        "['Savaş filmi', 'Dram', 'Tarihi']",
#        "['Polisiye', 'Gerilim', 'Romantik']",
#        "['Komedi', 'Polisiye', 'Gerilim']",
#        "['Macera', 'Korku', 'Tarihi']", "['Romantik', 'Gerilim']",
#        "['Animasyon', 'Müzikal', 'Romantik']",
#        "['Aksiyon', 'Dram', 'Dövüş']",
#        "['Savaş filmi', 'Dram', 'Polisiye', 'Tarihi']",
#        "['Müzikal', 'Dramatik komedi']",
#        "['Polisiye', 'Gerilim', 'Dram', 'Erotik']",
#        "['Aksiyon', 'Gerilim', 'Mahkeme']", "['Komedi', 'Müzik']",
#        "['Dram', 'Tarihi', 'Müzik']", "['Dram', 'Animasyon', 'Romantik']",
#        "['Dram', 'Gerilim', 'Aksiyon']",
#        "['Korku', 'Gerilim', 'Aksiyon']", "['Dram', 'Dramatik komedi']",
#        "['Bilimkurgu', 'Animasyon']", "['Müzik', 'Biyografik', 'Dram']",
#        "['Aile', 'Macera', 'Fantastik']",
#        "['Gerilim', 'Bilimkurgu', 'Fantastik']",
#        "['Fantastik', 'Aile', 'Macera']",
#        "['Gerilim', 'Dram', 'Romantik']",
#        "['Tarihi', 'Dram', 'Biyografik']", "['Concert', 'Müzik']",
#        "['Aksiyon', 'Polisiye', 'Mahkeme']",
#        "['Dram', 'Biyografik', 'Müzik', 'Romantik']",
#        "['Dram', 'Komedi', 'Gerilim']", "['Macera', 'Polisiye']",
#        "['Dövüş', 'Aksiyon', 'Gerilim']",
#        "['Animasyon ', 'Macera', 'Komedi']",
#        "['Polisiye', 'Dramatik komedi']",
#        "['Müzikal', 'Komedi', 'Romantik']",
#        "['Biyografik ', 'Dram', 'Müzik', 'Romantik']",
#        "['Dram', 'Fantastik', 'Gerilim']",
#        "['Korku', 'Polisiye', 'Gerilim']",
#        "['Biyografik', 'Dram', 'Müzik']",
#        "['Komedi', 'Aksiyon', 'Polisiye']",
#        "['Romantik', 'Fantastik', 'Komedi']",
#        "['Bilimkurgu', 'Komedi', 'Romantik']",
#        "['Fantastik', 'Macera', 'Komedi']",
#        "['Biyografik', 'Dramatik komedi', 'Dram', 'Komedi']",
#        "['Aksiyon', 'Dramatik komedi']",
#        "['Western', 'Dram', 'Biyografik', 'Aksiyon']",
#        "['Animasyon', 'Aile', 'Macera', 'Tarihi']",
#        "['Biyografik', 'Gerilim', 'Aksiyon', 'Dram']",
#        "['Aksiyon', 'Gerilim', 'Dövüş']",
#        "['Biyografik', 'Dram', 'Romantik']",
#        "['Tarihi', 'Dramatik komedi']",
#        "['Polisiye', 'Aksiyon', 'Gerilim']",
#        "['Polisiye', 'Fantastik', 'Gerilim']",
#        "['Dramatik komedi', 'Macera', 'Biyografik']",
#        "['Dramatik komedi', 'Erotik', 'Romantik']",
#        "['Tarihi', 'Aksiyon', 'Macera']",
#        "['Macera', 'Aksiyon', 'Gerilim']",
#        "['Aksiyon', 'Polisiye', 'Komedi']",
#        "['Dram', 'Komedi', 'Fantastik', 'Romantik']",
#        "['Dram', 'Romantik', 'Tarihi']",
#        "['Fantastik', 'Romantik', 'Dram']",
#        "['Animasyon', 'Komedi', 'Bilimkurgu', 'Macera']",
#        "['Tarihi', 'Dram', 'Aksiyon']",
#        "['Aksiyon', 'Biyografik', 'Western']",
#        "['Polisiye', 'Dramatik komedi', 'Komedi', 'Gerilim']",
#        "['Biyografik', 'Macera']", "['Dram', 'Biyografik ', 'Tarihi']",
#        "['Komedi', 'Polisiye', 'Dram']",
#        "['Savaş filmi', 'Aksiyon', 'Tarihi']",
#        "['Komedi', 'Macera', 'Romantik']",
#        "['Gerilim', 'Aksiyon', 'Bilimkurgu']",
#        "['Aksiyon', 'Komedi', 'Bilimkurgu']",
#        "['Animasyon', 'Macera', 'Komedi', 'Aile', 'Bilimkurgu']",
#        "['Dram', 'Biyografik', 'Sport event']",
#        "['Komedi', 'Macera', 'Korku']", "['Polisiye', 'Macera']",
#        "['Komedi', 'Dram', 'Müzik']",
#        "['Tarihi', 'Dram', 'Aksiyon', 'Macera']",
#        "['Tarihi', 'Polisiye', 'Macera']",
#        "['Dövüş', 'Dram', 'Romantik']", "['Polisiye', 'Casusluk']",
#        "['Korku', 'Romantik', 'Gerilim']", "['Mahkeme', 'Gerilim']",
#        "['Komedi', 'Fantastik', 'Aksiyon', 'Macera']",
#        "['Fantastik', 'Aksiyon', 'Dram']",
#        "['Biyografik', 'Dövüş', 'Aksiyon']",
#        "['Komedi', 'Casusluk', 'Aksiyon']",
#        "['Korku', 'Komedi', 'Aksiyon']", "['Korku', 'Biyografik']",
#        "['Korku', 'Fantastik', 'Romantik']",
#        "['Gerilim', 'Korku', 'Polisiye', 'Dram']",
#        "['Komedi', 'Savaş filmi']",
#        "['Aksiyon', 'Macera', 'Tarihi', 'Fantastik']",
#        "['Müzik', 'Polisiye', 'Romantik', 'Dram']",
#        "['Romantik', 'Müzikal']", "['Biyografik ', 'Dram', 'Romantik']",
#        "['Animasyon ', 'Macera']",
#        "['Biyografik', 'Dram', 'Savaş filmi']",
#        "['Epik', 'Macera', 'Dram']", "['Müzikal']",
#        "['Savaş filmi', 'Dram', 'Gerilim']",
#        "['Dramatik komedi', 'Savaş filmi']",
#        "['Western', 'Tarihi', 'Aksiyon']", "['Dram', 'Casusluk']",
#        "['Müzikal', 'Dram', 'Aile', 'Romantik']",
#        "['Dram', 'Polisiye', 'Romantik']",
#        "['Western', 'Macera', 'Aksiyon']",
#        "['Savaş filmi', 'Romantik', 'Dram']",
#        "['Müzikal', 'Aile', 'Dram']", "['Western', 'Gerilim', 'Dram']",
#        "['Komedi', 'Tarihi', 'Erotik']",
#        "['Dram', 'Romantik', 'Dramatik komedi']",
#        "['Polisiye', 'Gerilim', 'Biyografik']",
#        "['Animasyon ', 'Komedi', 'Macera']",
#        "['Gerilim', 'Aksiyon', 'Dram', 'Savaş filmi']",
#        "['Dramatik komedi', 'Fantastik', 'Sport event']",
#        "['Macera', 'Savaş filmi']",
#        "['Dram', 'Biyografik', 'Savaş filmi']",
#        "['Komedi', 'Dram', 'Korku', 'Fantastik']",
#        "['Dram', 'Gerilim', 'Komedi']",
#        "['Macera', 'Dövüş', 'Fantastik', 'Aksiyon']",
#        "['Müzikal', 'Aile']", "['Aksiyon', 'Biyografik', 'Macera']",
#        "['Dram', 'Komedi', 'Müzikal']",
#        "['Savaş filmi', 'Dram', 'Tarihi', 'Aksiyon']",
#        "['Komedi', 'Animasyon', 'Macera']",
#        "['Tarihi', 'Aksiyon', 'Dram', 'Savaş filmi']",
#        "['Dram', 'Savaş filmi', 'Tarihi']",
#        "['Animasyon', 'Komedi', 'Aile', 'Bilimkurgu', 'Macera']",
#        "['Macera', 'Komedi', 'Dram', 'Aile']",
#        "['Aksiyon', 'Dram', 'Tarihi', 'Savaş filmi']",
#        "['Dram', 'Romantik', 'Savaş filmi']",
#        "['Biyografik', 'Polisiye']",
#        "['Aksiyon', 'Aile', 'Gerilim', 'Dramatik komedi']",
#        "['Tarihi', 'Macera']",
#        "['Komedi', 'Romantik', 'Macera', 'Polisiye']",
#        "['Animasyon', 'Komedi', 'Bilimkurgu']", "['Gerilim', 'Erotik']",
#        "['Animasyon', 'Bilimkurgu', 'Aksiyon', 'Dram']",
#        "['Dram', 'Komedi', 'Savaş filmi']",
#        "['Bilimkurgu', 'Western', 'Aksiyon', 'Macera']",
#        "['Biyografik', 'Müzikal']", "['Macera', 'Romantik', 'Dram']",
#        "['Animasyon', 'Aile', 'Komedi', 'Dram']", "['Dövüş', 'Dram']",
#        "['Komedi', 'Müzik', 'Romantik', 'Dram']",
#        "['Gerilim', 'Mahkeme']", "['Polisiye', 'Aksiyon', 'Komedi']",
#        "['Aksiyon', 'Korku', 'Gerilim', 'Komedi']",
#        "['Casusluk', 'Aksiyon', 'Macera']",
#        "['Komedi', 'Animasyon', 'Aile', 'Macera']",
#        "['Fantastik', 'Komedi', 'Bilimkurgu']",
#        "['Aksiyon', 'Bilimkurgu', 'Savaş filmi']",
#        "['Macera', 'Aile', 'Animasyon', 'Fantastik']",
#        "['Macera', 'Fantastik', 'Komedi']",
#        "['Macera', 'Komedi', 'Romantik']",
#        "['Biyografik ', 'Polisiye', 'Dram']",
#        "['Dram', 'Komedi', 'Fantastik']", "['Komedi', 'Gerilim']",
#        "['Korku', 'Gerilim', 'Macera']",
#        "['Dram', 'Romantik', 'Macera', 'Savaş filmi']",
#        "['Müzik', 'Komedi']", "['Biyografik ', 'Dram', 'Gerilim']",
#        "['Macera', 'Dram', 'Romantik']", "['Macera', 'Tarihi', 'Dram']",
#        "['Aksiyon', 'Romantik']", "['Fantastik', 'Korku', 'Müzik']",
#        "['Gerilim', 'Tarihi']",
#        "['Dramatik komedi', 'Tarihi', 'Romantik']",
#        "['Animasyon', 'Aksiyon', 'Macera']",
#        "['Biyografik', 'Dram', 'Komedi']",
#        "['Animasyon', 'Fantastik', 'Aile', 'Macera']",
#        "['Macera', 'Aksiyon', 'Dram', 'Savaş filmi']",
#        "['Bilimkurgu', 'Korku', 'Fantastik']",
#        "['Komedi', 'Bilimkurgu', 'Macera']", "['Aile', 'Animasyon']",
#        "['Dram', 'Experimental']", "['Animasyon ', 'Çizgi film']",
#        "['Animasyon ', 'Aile', 'Komedi']", "['Macera', 'Komedi', 'Dram']",
#        "['Macera', 'Western', 'Aksiyon']",
#        "['Aksiyon', 'Gerilim', 'Komedi']",
#        "['Animasyon ', 'Komedi', 'Müzikal']",
#        "['Gerilim', 'Polisiye', 'Aksiyon', 'Dram']",
#        "['Dramatik komedi', 'Müzikal']", "['Biyografik', 'Komedi']",
#        "['Fantastik', 'Aksiyon', 'Korku', 'Gerilim']",
#        "['Komedi', 'Animasyon ', 'Aile']", "['Tarihi', 'Romantik']",
#        "['Komedi', 'Bilimkurgu', 'Romantik', 'Müzik']",
#        "['Polisiye', 'Bilimkurgu', 'Dram']",
#        "['Aksiyon', 'Casusluk', 'Gerilim', 'Polisiye']",
#        "['Mahkeme', 'Dramatik komedi']",
#        "['Fantastik', 'Tarihi', 'Gerilim', 'Western']",
#        "['Macera', 'Tarihi']", "['Komedi', 'Dram', 'Savaş filmi']",
#        "['Komedi', 'Müzikal', 'Romantik']",
#        "['Macera', 'Gerilim', 'Aksiyon', 'Polisiye']",
#        "['Aile', 'Çizgi film']", "['Polisiye', 'Komedi', 'Romantik']",
#        "['Aksiyon', 'Bilimkurgu', 'Korku']",
#        "['Fantastik', 'Korku', 'Dram', 'Gerilim']",
#        "['Fantastik', 'Tarihi', 'Aksiyon']",
#        "['Dram', 'Polisiye', 'Komedi']",
#        "['Fantastik', 'Komedi', 'Aile', 'Macera']",
#        "['Dövüş', 'Aksiyon', 'Macera']", "['Western', 'Komedi']",
#        "['Müzik', 'Dram', 'Romantik']",
#        "['Aksiyon', 'Biyografik ', 'Dram']", "['Animasyon ', 'Komedi']",
#        "['Biyografik ', 'Tarihi']", "['Tarihi', 'Dram', 'Savaş filmi']",
#        "['Dramatik komedi', 'Dram', 'Komedi', 'Romantik']",
#        "['Gerilim', 'Biyografik ', 'Dram']",
#        "['Müzikal', 'Dram', 'Aile']", "['Dram', 'Komedi', 'Mahkeme']",
#        "['Animasyon', 'Bilimkurgu']",
#        "['Dram', 'Fantastik', 'Bilimkurgu']",
#        "['Savaş filmi', 'Dram', 'Aksiyon', 'Tarihi']",
#        "['Polisiye', 'Gerilim', 'Komedi']",
#        "['Komedi', 'Macera', 'Polisiye']", "['Aksiyon', 'Biyografik']",
#        "['Gerilim', 'Dram', 'Fantastik']",
#        "['Savaş filmi', 'Aksiyon', 'Macera', 'Dram', 'Romantik']",
#        "['Animasyon', 'Aksiyon', 'Bilimkurgu']",
#        "['Dram', 'Savaş filmi', 'Casusluk']",
#        "['Dramatik komedi', 'Gerilim', 'Romantik']",
#        "['Aksiyon', 'Komedi', 'Gerilim']",
#        "['Aksiyon', 'Polisiye', 'Bilimkurgu']",
#        "['Komedi', 'Fantastik', 'Bilimkurgu']",
#        "['Animasyon', 'Bilimkurgu', 'Macera']",
#        "['Western', 'Komedi', 'Aksiyon']",
#        "['Komedi', 'Müzikal', 'Aksiyon']",
#        "['Gerilim', 'Aksiyon', 'Macera', 'Polisiye', 'Dram']",
#        "['Casusluk', 'Romantik', 'Gerilim', 'Komedi']",
#        "['Romantik', 'Animasyon']", "['Korku', 'Komedi', 'Gerilim']",
#        "['Dram', 'Tarihi', 'Komedi']", "['Komedi', 'Romantik', 'Müzik']",
#        "['Müzik']", "['Aksiyon', 'Romantik', 'Gerilim']",
#        "['Casusluk', 'Macera', 'Komedi', 'Aksiyon']",
#        "['Komedi', 'Gerilim', 'Aksiyon', 'Polisiye']",
#        "['Animasyon', 'Macera', 'Komedi', 'Bilimkurgu', 'Aile']",
#        "['Dramatik komedi', 'Romantik', 'Dram']",
#        "['Müzikal', 'Fantastik', 'Aile']",
#        "['Gerilim', 'Fantastik', 'Aksiyon']",
#        "['Dramatik komedi', 'Fantastik', 'Biyografik']",
#        "['Bilimkurgu', 'Dram', 'Gerilim', 'Korku', 'Fantastik']",
#        "['Polisiye', 'Komedi', 'Aksiyon']",
#        "['Macera', 'Dramatik komedi', 'Aile']",
#        "['Aile', 'Macera', 'Animasyon']",
#        "['Dram', 'Biyografik', 'Polisiye']"], dtype=object)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5261 entries, 0 to 5260
# Data columns (total 7 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   film adi          5261 non-null   object
#  1   ozet ve detaylar  5261 non-null   object
#  2   tur               5261 non-null   object
#  3   oyuncular         5261 non-null   object
#  4   yonetmen          5261 non-null   object
#  5   vizyon tarihi     5261 non-null   object
#  6   sure              5261 non-null   object
# dtypes: object(7)
# memory usage: 287.8+ KB

# %%
df.isna().sum()
# Out:
# film adi            0
# ozet ve detaylar    0
# tur                 0
# oyuncular           0
# yonetmen            0
# vizyon tarihi       0
# sure                0
# dtype: int64

# %%
nltk.download("stopwords")
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\Mustafa\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
import string
from nltk.corpus import stopwords

# %%
string.punctuation
# Out:
# '!"#$%&\'()*+,-./:;<=>?@[\\]^_`{|}~'

# %%
dolgular = stopwords.words("turkish")
dolgular
# Out:
# ['acaba',
#  'ama',
#  'aslında',
#  'az',
#  'bazı',
#  'belki',
#  'biri',
#  'birkaç',
#  'birşey',
#  'biz',
#  'bu',
#  'çok',
#  'çünkü',
#  'da',
#  'daha',
#  'de',
#  'defa',
#  'diye',
#  'eğer',
#  'en',
#  'gibi',
#  'hem',
#  'hep',
#  'hepsi',
#  'her',
#  'hiç',
#  'için',
#  'ile',
#  'ise',
#  'kez',
#  'ki',
#  'kim',
#  'mı',
#  'mu',
#  'mü',
#  'nasıl',
#  'ne',
#  'neden',
#  'nerde',
#  'nerede',
#  'nereye',
#  'niçin',
#  'niye',
#  'o',
#  'sanki',
#  'şey',
#  'siz',
#  'şu',
#  'tüm',
#  've',
#  'veya',
#  'ya',
#  'yani']

# %%
s = "Hey! Naber? İyilik, senden... Ben de iyiyim."
s = s.translate(str.maketrans ('', '', string.punctuation))

# %%
s
# Out:
# 'Hey Naber İyilik senden Ben de iyiyim'

# %%
analiz = analyzer.lemmatize(s)
analiz
# Out:
# [('Hey', ['hey']),
#  ('Naber', ['Naber']),
#  ('İyilik', ['iyi']),
#  ('senden', ['se', 'sen']),
#  ('Ben', ['ben']),
#  ('de', ['demek', 'de']),
#  ('iyiyim', ['iyi'])]

# %%
for el in analiz:
    print(el[1][-1])
# Out:
# hey
# Naber
# iyi
# sen
# ben
# de
# iyi

# %%
ornek = df.iloc[13]["ozet ve detaylar"]
ornek
# Out:
# "25 yaşına gelen insanların, yaşlanmayı durdurmak için var güçleriyle çalışmak zorunda olduğu bir gelecekte geçen filmde, zaman gerçekten para ve güç demek. Will Salas (Justin Timberlake), bir hata sonucu cinayetten hüküm giyer ve hapishaneden kurtulmak için tek şansı gerçek yüzünü gördüğü sistemi çökertmektir. Zira zamanın rahatlıkla satın alınabildiği bu sistemde zenginler sonsuza kadar genç kalarak yaşarken fakir ve güçsüz olan ise ölerek, elenir. Üstelik kendi yaşayamadıkları yıllar başkalarının hayatlarına eklenir. Güçs üz olanlar sadece bir gün daha hayatta kalabilmek için 'zaman' dilenir, ödünç alır hatta bazen zamanı çalar. Will Salas ise bütün bu yozlaşmış sisteme karşı baş kaldırır... Başrollerini son dönemde müzik çalışmalarına ara veren ve sinemaya yönelen Justin Timberlake ile yeni Scarlett Johansson olarak anılan Amanda Seyfried'in paylaştığı filmin yardımcı oyuncu kadrosunda ise Olivia Wilde, Alex Pettyfer, Cillian Murphy gibi isimler var.Daha önce Gattaca, S1m0ne ve Lord of War'ı hem yazıp hem yöneten, The Truman Show ve The Terminal gibi filmlerin senaryosunu kaleme alan Andrew Niccol'un son projesi büyük beklenti yaratıyor..."

# %%
ornek.translate(str.maketrans ('', '', string.punctuation))
# Out:
# '25 yaşına gelen insanların yaşlanmayı durdurmak için var güçleriyle çalışmak zorunda olduğu bir gelecekte geçen filmde zaman gerçekten para ve güç demek Will Salas Justin Timberlake bir hata sonucu cinayetten hüküm giyer ve hapishaneden kurtulmak için tek şansı gerçek yüzünü gördüğü sistemi çökertmektir Zira zamanın rahatlıkla satın alınabildiği bu sistemde zenginler sonsuza kadar genç kalarak yaşarken fakir ve güçsüz olan ise ölerek elenir Üstelik kendi yaşayamadıkları yıllar başkalarının hayatlarına eklenir Güçs üz olanlar sadece bir gün daha hayatta kalabilmek için zaman dilenir ödünç alır hatta bazen zamanı çalar Will Salas ise bütün bu yozlaşmış sisteme karşı baş kaldırır Başrollerini son dönemde müzik çalışmalarına ara veren ve sinemaya yönelen Justin Timberlake ile yeni Scarlett Johansson olarak anılan Amanda Seyfriedin paylaştığı filmin yardımcı oyuncu kadrosunda ise Olivia Wilde Alex Pettyfer Cillian Murphy gibi isimler varDaha önce Gattaca S1m0ne ve Lord of Warı hem yazıp hem yöneten The Truman Show ve The Terminal gibi filmlerin senaryosunu kaleme alan Andrew Niccolun son projesi büyük beklenti yaratıyor'

# %%
ornek = "film,çok güzel.tavsiye ederim."
ornek.translate(str.maketrans ('', '', string.punctuation))
# Out:
# 'filmçok güzeltavsiye ederim'

# %%
from nltk.tokenize import RegexpTokenizer

tokenizer = RegexpTokenizer(r"\w+")
tokenizer.tokenize(ornek)
# Out:
# ['film', 'çok', 'güzel', 'tavsiye', 'ederim']

# %%
def clean_doc(doc, tok):
    """
    Args:
        doc (str): Köklerine ayrılacak doküman.
        tok (RegexpTokenizer): Instance of RegexpTokenizer from nltk.tokenize.

    Returns:
        [str]: List of lemmatized words from the doc argument without punctuation and stop words.
    
    Ex: clean_doc("film,çok güzel.tavsiye ederim.", tokenizer) -> ['film', 'güzel', 'tavsiye', 'eder']
    """
    tokens = tok.tokenize(doc) # doc'ları kelimelere ayır, noktalama işaretlerini çıkar
    clean_tokens = [tok for tok in tokens if tok not in dolgular] # stop word'leri ayıkla
    analiz = analyzer.lemmatize(" ".join(clean_tokens)) # token'ları ayıkla
    return [el[1][-1] for el in analiz] # temizlenmiş token'ları liste olarak döndür

# %%
tokenizer = RegexpTokenizer(r"\w+")
clean_doc(ornek, tokenizer)
# Out:
# ['film', 'güzel', 'tavsiye', 'eder']

# %%
df.head()
# Out:
#                                       film adi  \
# 0                                       Bergen
# 1                                Kirpi Sonic 2
# 2  Fantastik Canavarlar: Dumbledore'un Sırları
# 3                               Aykut Enişte 2
# 4                                      Morbius
#
#                                     ozet ve detaylar  \
# 0  Arabeskin unutulmayan kadın seslerinden biri o...
# 1  Çocuk filmi \n\n\nKirpi Sonic filminin devam h...
# 2  Karanlık büyücü Gellert Grindelwald, büyücülük...
# 3  Aykut Enişte 2, sevdiği kadınla evlilik arifes...
# 4  Morbius, hastalığına deva bulmaya çalışırken b...
#
#                                   tur  \
# 0              ['Dram', 'Biyografik']
# 1     ['Animasyon', 'Aile', 'Macera']
# 2             ['Fantastik', 'Macera']
# 3                          ['Komedi']
# 4  ['Aksiyon', 'Fantastik', 'Macera']
#
#                                            oyuncular  \
# 0  ['Farah Zeynep Abdullah', 'Erdal Beşikçioğlu',...
# 1              ['Jim Carrey', 'James Marsden', None]
# 2   ['Eddie Redmayne', 'Jude Law', 'Mads Mikkelsen']
# 3  ['Cem Gelinoğlu', 'Melis Babadağ', 'Hakan Yılm...
# 4  ['Jared Leto', 'Matt Smith (XI)', 'Adria Arjona']
#
#                           yonetmen  vizyon tarihi     sure
# 0  ['Mehmet Binay', 'Caner Alper']    4 Mart 2022  2s 26dk
# 1                  ['Jeff Fowler']   8 Nisan 2022   2s 2dk
# 2                  ['David Yates']  15 Nisan 2022  2s 22dk
# 3                ['Onur Bilgetay']  3 Aralık 2021  1s 55dk
# 4              ['Daniel Espinosa']   1 Nisan 2022  1s 45dk

# %%
# bu işlem uzun sürebilir
# uzayda bir kavanozun kapağını açıp kapattığınızda ve kavanozu Ay'a doğru
# fırlattığınızda kavanoz içindeki boşluk hareket eder mi?
import ast

def extract_features(row, tokenizer):
    filmAdi = clean_doc(row["film adi"], tokenizer)
    tur = row["tur"]
    oyuncular = row["oyuncular"]
    yonetmen = row["yonetmen"]
    return filmAdi + ast.literal_eval(tur) +ast.literal_eval(oyuncular) + ast.literal_eval(yonetmen)

df["clean"] = df.apply(lambda row: extract_features(row, tokenizer), axis=1)

# %%
df.head()
# Out:
#                                       film adi  \
# 0                                       Bergen
# 1                                Kirpi Sonic 2
# 2  Fantastik Canavarlar: Dumbledore'un Sırları
# 3                               Aykut Enişte 2
# 4                                      Morbius
#
#                                     ozet ve detaylar  \
# 0  Arabeskin unutulmayan kadın seslerinden biri o...
# 1  Çocuk filmi \n\n\nKirpi Sonic filminin devam h...
# 2  Karanlık büyücü Gellert Grindelwald, büyücülük...
# 3  Aykut Enişte 2, sevdiği kadınla evlilik arifes...
# 4  Morbius, hastalığına deva bulmaya çalışırken b...
#
#                                   tur  \
# 0              ['Dram', 'Biyografik']
# 1     ['Animasyon', 'Aile', 'Macera']
# 2             ['Fantastik', 'Macera']
# 3                          ['Komedi']
# 4  ['Aksiyon', 'Fantastik', 'Macera']
#
#                                            oyuncular  \
# 0  ['Farah Zeynep Abdullah', 'Erdal Beşikçioğlu',...
# 1              ['Jim Carrey', 'James Marsden', None]
# 2   ['Eddie Redmayne', 'Jude Law', 'Mads Mikkelsen']
# 3  ['Cem Gelinoğlu', 'Melis Babadağ', 'Hakan Yılm...
# 4  ['Jared Leto', 'Matt Smith (XI)', 'Adria Arjona']
#
#                           yonetmen  vizyon tarihi     sure  \
# 0  ['Mehmet Binay', 'Caner Alper']    4 Mart 2022  2s 26dk
# 1                  ['Jeff Fowler']   8 Nisan 2022   2s 2dk
# 2                  ['David Yates']  15 Nisan 2022  2s 22dk
# 3                ['Onur Bilgetay']  3 Aralık 2021  1s 55dk
# 4              ['Daniel Espinosa']   1 Nisan 2022  1s 45dk
#
#                                                clean
# 0  [Bergen, Dram, Biyografik, Farah Zeynep Abdull...
# 1  [kirpi, Sonic, 2, Animasyon, Aile, Macera, Jim...
# 2  [fantastik, canavar, Dumbledore, un, sır, Fant...
# 3  [Aykut, enişte, 2, Komedi, Cem Gelinoğlu, Meli...
# 4  [Morbius, Aksiyon, Fantastik, Macera, Jared Le...

# %%
import random
for i in range(3):
    rand_idx = random.randrange(len(df))
    ozet = df.iloc[rand_idx]["ozet ve detaylar"]
    print("Orijinal:")
    print(ozet + "\n")
    print("Temizlenmiş:")
    print(" ".join(df.iloc[rand_idx]["clean"]) + "\n")  
    print("/" * 50 + "\n")
# Out:
# Orijinal:
# Üç genç kadın, trajik nedenlerle Magdelena Manastırı’nda bulurlar kendilerini. Yıl 1964. Diğer birçok benzeri manastırlarda da olduğu üzere buralar, hapishane gibi işlemektedir. Genç kızlar, ev işi, çamaşır ya da zor başka işleri yapmak zorundadırlar. Buna mecbur kılınırlar. O dönem, Teokratik Katolik İrlanda’daki mevcut manastırlardan bazıları “düşmüş” adledilen kızlar içindir. Burada genç kızlar süresiz olarak hapsedilirler ve çarptırıldıkları ıstırap yüklü cezalara katlanırlar. Bu süreç fiziksel olarak aşırı derecede yıpranmalarına ve ruhsal sağlıklarının bozulmasına neden olur. Kızlar birleştikçe tek çıkış yollarının Magdelana hapishanesinden kaçmak olduğuna kanaat getirirler. Ancak kaçık rahibe Bridget ile böyle bir kaçış planı her türlü şansı sınırlandırır. 2002 Venedik Film Festivalin’de olay yaratan filmin yönetmeni Peter Mullan, Vatikan tarafından ziyadesi ile tepki almıştır.
#
# Temizlenmiş:
# günahkâr rahip Dram Anne-Marie Duff Nora-Jane Noone Dorothy Duffy Peter Mullan
#
# //////////////////////////////////////////////////
#
# Orijinal:
# Amerika’daki ekonomik buhran döneminde tetikçilik yaparak hayatını kazanan Michael Sullivan, John Rooney’nin hesabına çalışmaktadır. Fakat Rooney’nin oğlu, babasına kendisinden daha yakın olan bu adamı harcayacak türden dolaplar çevirir. Sullivan, hiç istemediği halde kendi oğlunun da olaya karışması sonucu tehlikeli bir açmaza düşer.Olayların gelişmesiyle birlikte, hem cinayet mahali fotoğrafçısı hem de suikastçı olan Maguire, Sullivan’ın peşine takılır. Sullivan, ne pahasına olursa olsun oğlunu korumak zorundadır.
#
# Temizlenmiş:
# azap yol Dram Gerilim Tom Hanks Tyler Hoechlin Paul Newman Sam Mendes
#
# //////////////////////////////////////////////////
#
# Orijinal:
# Başarılı ve sert bir polis olan Tom Brant (Jason Statham) şehre korku salan Blitz adlı seri katili yakalamak için görevlendirilir. Olaylar geliştikçe işin içinde kendisinin de olduğunu, birilerinin onu hedef yaptığını anlar. Uyuşturucudan kurtulmaya çalışan arkadaşını tehdit eden Blitz'in listesinde Brant te mi vardır? Film Ağustos 2009'da Londra'da çekildi. Blitz, Lionsgate UK tarafından yapımı gerçekleştirilen ilk film olma üzelliği taşıyor.
#
# Temizlenmiş:
# Blitz Gerilim Aksiyon Jason Statham Paddy Considine Aidan Gillen Elliott Lester
#
# //////////////////////////////////////////////////

# %%
df.to_csv("filmler_clean.csv", index=False)

# %%
df_diskten = pd.read_csv("filmler_clean.csv")

# %%
df_diskten.head()
# Out:
#                                       film adi  \
# 0                                       Bergen
# 1                                Kirpi Sonic 2
# 2  Fantastik Canavarlar: Dumbledore'un Sırları
# 3                               Aykut Enişte 2
# 4                                      Morbius
#
#                                     ozet ve detaylar  \
# 0  Arabeskin unutulmayan kadın seslerinden biri o...
# 1  Çocuk filmi \n\n\nKirpi Sonic filminin devam h...
# 2  Karanlık büyücü Gellert Grindelwald, büyücülük...
# 3  Aykut Enişte 2, sevdiği kadınla evlilik arifes...
# 4  Morbius, hastalığına deva bulmaya çalışırken b...
#
#                                   tur  \
# 0              ['Dram', 'Biyografik']
# 1     ['Animasyon', 'Aile', 'Macera']
# 2             ['Fantastik', 'Macera']
# 3                          ['Komedi']
# 4  ['Aksiyon', 'Fantastik', 'Macera']
#
#                                            oyuncular  \
# 0  ['Farah Zeynep Abdullah', 'Erdal Beşikçioğlu',...
# 1              ['Jim Carrey', 'James Marsden', None]
# 2   ['Eddie Redmayne', 'Jude Law', 'Mads Mikkelsen']
# 3  ['Cem Gelinoğlu', 'Melis Babadağ', 'Hakan Yılm...
# 4  ['Jared Leto', 'Matt Smith (XI)', 'Adria Arjona']
#
#                           yonetmen  vizyon tarihi     sure  \
# 0  ['Mehmet Binay', 'Caner Alper']    4 Mart 2022  2s 26dk
# 1                  ['Jeff Fowler']   8 Nisan 2022   2s 2dk
# 2                  ['David Yates']  15 Nisan 2022  2s 22dk
# 3                ['Onur Bilgetay']  3 Aralık 2021  1s 55dk
# 4              ['Daniel Espinosa']   1 Nisan 2022  1s 45dk
#
#                                                clean
# 0  ['Bergen', 'Dram', 'Biyografik', 'Farah Zeynep...
# 1  ['kirpi', 'Sonic', '2', 'Animasyon', 'Aile', '...
# 2  ['fantastik', 'canavar', 'Dumbledore', 'un', '...
# 3  ['Aykut', 'enişte', '2', 'Komedi', 'Cem Gelino...
# 4  ['Morbius', 'Aksiyon', 'Fantastik', 'Macera', ...

# %%
kelime2index = {}
index2kelime = {}

# %%
kelime2index["<UNK>"] = 0
index2kelime[0] = "<UNK>"

# %%
clean_col = df["clean"]
clean_col
# Out:
# 0       [Bergen, Dram, Biyografik, Farah Zeynep Abdull...
# 1       [kirpi, Sonic, 2, Animasyon, Aile, Macera, Jim...
# 2       [fantastik, canavar, Dumbledore, un, sır, Fant...
# 3       [Aykut, enişte, 2, Komedi, Cem Gelinoğlu, Meli...
# 4       [Morbius, Aksiyon, Fantastik, Macera, Jared Le...
#                               ...
# 5256    [süper, baba, Komedi, Adam Sandler, Joey Laure...
# 5257    [anahtar, Dram, Aksiyon, Hatice Tezcan, Cihan ...
# 5258    [kahraman, iki, Animasyon , Komedi, None, None...
# 5259    [Neruda, Dram, Biyografik, Polisiye, Luis Gnec...
# 5260    [müebbet, kuş, Komedi, R. Lee Ermey, Eddie Mur...
# Name: clean, Length: 5261, dtype: object

# %%
len(clean_col.values), len(df)
# Out:
# (5261, 5261)

# %%
i = 1
for doc in clean_col.values:
    for token in doc:
        if token in kelime2index:
            continue
        
        kelime2index[token] = i
        index2kelime[i] = token
        i += 1

# %%
kelime2index
# Out:
# {'<UNK>': 0,
#  'Bergen': 1,
#  'Dram': 2,
#  'Biyografik': 3,
#  'Farah Zeynep Abdullah': 4,
#  'Erdal Beşikçioğlu': 5,
#  'Tilbe Saran': 6,
#  'Mehmet Binay': 7,
#  'Caner Alper': 8,
#  'kirpi': 9,
#  'Sonic': 10,
#  '2': 11,
#  'Animasyon': 12,
#  'Aile': 13,
#  'Macera': 14,
#  'Jim Carrey': 15,
#  'James Marsden': 16,
#  None: 17,
#  'Jeff Fowler': 18,
#  'fantastik': 19,
#  'canavar': 20,
#  'Dumbledore': 21,
#  'un': 22,
#  'sır': 23,
#  'Fantastik': 24,
#  'Eddie Redmayne': 25,
#  'Jude Law': 26,
#  'Mads Mikkelsen': 27,
#  'David Yates': 28,
#  'Aykut': 29,
#  'enişte': 30,
#  'Komedi': 31,
#  'Cem Gelinoğlu': 32,
#  'Melis Babadağ': 33,
#  'Hakan Yılmaz': 34,
#  'Onur Bilgetay': 35,
#  'Morbius': 36,
#  'Aksiyon': 37,
#  'Jared Leto': 38,
#  'Matt Smith (XI)': 39,
#  'Adria Arjona': 40,
#  'Daniel Espinosa': 41,
#  'kırmız': 42,
#  'Domee Shi': 43,
#  'kar': 44,
#  'Hazar Ergüçlü': 45,
#  'Ozan Uygun': 46,
#  'Halil Babür': 47,
#  'Emre Erdoğdu': 48,
#  'kesişmek': 49,
#  'iyi': 50,
#  'var': 51,
#  'ermek': 52,
#  'İsmail Hacıoğlu': 53,
#  'Rahman Başel': 54,
#  'Alayça Öztürk': 55,
#  'Özer Feyzioğlu': 56,
#  'örümcek': 57,
#  'adam': 58,
#  'ev': 59,
#  'dönmek': 60,
#  'yok': 61,
#  'Tom Holland': 62,
#  'Zendaya': 63,
#  'Benedict Cumberbatch': 64,
#  'Jon Watts': 65,
#  'The': 66,
#  'batmak': 67,
#  'Polisiye': 68,
#  'Gerilim': 69,
#  'Robert Pattinson': 70,
#  'Zoë Kravitz': 71,
#  'Paul Dano': 72,
#  'Matt Reeves': 73,
#  'doktor': 74,
#  'Strange': 75,
#  'çok': 76,
#  'evre': 77,
#  'çılgın': 78,
#  'Elizabeth Olsen': 79,
#  'Rachel McAdams': 80,
#  'Sam Raimi': 81,
#  'Dilberay': 82,
#  'Büşra Pekin': 83,
#  'Zeliha Kendirci': 84,
#  'Nursel Köse': 85,
#  'Ketche': 86,
#  'doru': 87,
#  'macera': 88,
#  'orman': 89,
#  'Arkın Aktaç': 90,
#  'zaman': 91,
#  'karşı': 92,
#  'Bilimkurgu': 93,
#  'Amanda Seyfried': 94,
#  'Justin Timberlake': 95,
#  'Cillian Murphy': 96,
#  'Andrew Niccol': 97,
#  'gri': 98,
#  'el': 99,
#  'ton': 100,
#  'Romantik': 101,
#  'Jamie Dornan': 102,
#  'Dakota Johnson': 103,
#  'Jennifer Ehle': 104,
#  'Sam Taylor-Johnson': 105,
#  'recep': 106,
#  'İvedik': 107,
#  '6': 108,
#  'Şahan Gökbakar': 109,
#  'Nurullah Çelebi': 110,
#  'Somer Karvan': 111,
#  'Togan Gökbakar': 112,
#  'karmak': 113,
#  'Erotik': 114,
#  'Bella Heathcote': 115,
#  'James Foley': 116,
#  'Day': 117,
#  'bir': 118,
#  'adamı': 119,
#  'hikâye': 120,
#  'Ufuk Bayraktar': 121,
#  'Gizem Karaca': 122,
#  'Ahmet Varlı': 123,
#  'Uğur Bayraktar': 124,
#  'kayıp': 125,
#  'şehir': 126,
#  'Sandra Bullock': 127,
#  'Channing Tatum': 128,
#  'Daniel Radcliffe': 129,
#  'Aaron Nee': 130,
#  'Adam Nee': 131,
#  'kuzey': 132,
#  'Tarihi': 133,
#  'Alexander Skarsgård': 134,
#  'Nicole Kidman': 135,
#  'Claes Bang': 136,
#  'Robert Eggers': 137,
#  'Dune': 138,
#  'çöl': 139,
#  'gezegen': 140,
#  'Timothée Chalamet': 141,
#  'Rebecca Ferguson': 142,
#  'Oscar Isaac': 143,
#  'Denis Villeneuve': 144,
#  'hız': 145,
#  'öfke': 146,
#  '9': 147,
#  'Vin Diesel': 148,
#  'Michelle Rodriguez': 149,
#  'Jordana Brewster': 150,
#  'Justin Lin': 151,
#  'Venom': 152,
#  'zehir': 153,
#  'Tom Hardy': 154,
#  'Woody Harrelson': 155,
#  'Michelle Williams': 156,
#  'Andy Serkis': 157,
#  'gizli': 158,
#  'gerçek': 159,
#  'Korku': 160,
#  'Sarah Paulson': 161,
#  'Kiera Allen': 162,
#  'Pat Healy': 163,
#  'Aneesh Chaganty': 164,
#  'bura': 165,
#  'o': 166,
#  'kalmak': 167,
#  'Cameron Diaz': 168,
#  'Ashton Kutcher': 169,
#  'Lake Bell': 170,
#  'Tom Vaughan': 171,
#  'deha': 172,
#  'Chris Evans': 173,
#  'Mckenna Grace': 174,
#  'Lindsay Duncan': 175,
#  'Marc Webb': 176,
#  'ihanet': 177,
#  'Kristin Scott Thomas': 178,
#  'Sergi López': 179,
#  'Yvan Attal': 180,
#  'Catherine Corsini': 181,
#  'yedinci': 182,
#  'hayat': 183,
#  'Noomi Rapace': 184,
#  'Glenn Close': 185,
#  'Willem Dafoe': 186,
#  'Tommy Wirkola': 187,
#  'buz': 188,
#  'devir': 189,
#  '3': 190,
#  'dinozorlar': 191,
#  'şafak': 192,
#  'Carlos Saldanha': 193,
#  'Mike Thurmeier': 194,
#  'her': 195,
#  'şey': 196,
#  'yer': 197,
#  'aynı': 198,
#  'an': 199,
#  'Michelle Yeoh': 200,
#  'Ke Huy Quan': 201,
#  'Jamie Lee Curtis': 202,
#  'Daniel Scheinert': 203,
#  'Daniel Kwan': 204,
#  'ölüm': 205,
#  'aşk': 206,
#  'Blake Lively': 207,
#  'Michiel Huisman': 208,
#  'Harrison Ford': 209,
#  'Lee Toland Krieger': 210,
#  'kadın': 211,
#  'seks': 212,
#  'günlük': 213,
#  'Belén Fabra': 214,
#  'Leonardo Sbaraglia': 215,
#  'Llum Barrera': 216,
#  'Christian Molina': 217,
#  'uçmak': 218,
#  'plan': 219,
#  'Jodie Foster': 220,
#  'Michael Irby': 221,
#  'Assaf Cohen': 222,
#  'Robert Schwentke': 223,
#  'Enes': 224,
#  'batur': 225,
#  'kahraman': 226,
#  'Enes Batur': 227,
#  'Ömer Başdoğan': 228,
#  'Altan Erkekli': 229,
#  'Doğa Can Anafarta': 230,
#  'adamak': 231,
#  'kutsal': 232,
#  'kavga': 233,
#  'İsmail Filiz': 234,
#  'Esra Bilgiç': 235,
#  'Baki İlhan': 236,
#  'Emir Khalilzadeh': 237,
#  'ketenpere': 238,
#  'Şafak Sezer': 239,
#  'Hakan Ural': 240,
#  'Mehmet Esen': 241,
#  'Kamil Çetin': 242,
#  'intikam': 243,
#  'vakit': 244,
#  'Jason Statham': 245,
#  'Holt McCallany': 246,
#  'Josh Hartnett': 247,
#  'Guy Ritchie': 248,
#  'çağrı': 249,
#  'Anthony Quinn': 250,
#  'Irène Papas': 251,
#  'Michael Ansara': 252,
#  'Moustapha Akkad': 253,
#  'Avengers': 254,
#  'Endgame': 255,
#  'Robert Downey Jr.': 256,
#  'Mark Ruffalo': 257,
#  'Joe Russo': 258,
#  'Anthony Russo': 259,
#  'Harry': 260,
#  'Potter': 261,
#  'felsefe': 262,
#  'taşımak': 263,
#  'Rupert Grint': 264,
#  'Emma Watson': 265,
#  'Chris Columbus': 266,
#  'düş': 267,
#  'fabrika': 268,
#  'Kim Hagen Jensen': 269,
#  'düşman': 270,
#  'Vera Farmiga': 271,
#  'Peter Sarsgaard': 272,
#  'Isabelle Fuhrman': 273,
#  'Jaume Collet-Serra': 274,
#  'kök': 275,
#  'Ahu Türkpençe': 276,
#  'Lale Başar': 277,
#  'Savaş Alp Başar': 278,
#  'Deniz Akçay Katıksız': 279,
#  'Uncharted': 280,
#  'Mark Wahlberg': 281,
#  'Sophia Ali': 282,
#  'Ruben Fleischer': 283,
#  'Araf': 284,
#  '5': 285,
#  'aile': 286,
#  'Can Suoruç': 287,
#  'Tuğgül Küçükoğlu': 288,
#  'İrem İpek': 289,
#  'Uğur Kaplan': 290,
#  'kral': 291,
#  'Richard': 292,
#  'yükselmek': 293,
#  'şampiyon': 294,
#  'Will Smith': 295,
#  'Aunjanue Ellis': 296,
#  'Saniyya Sidney': 297,
#  'Reinaldo Marcus Green': 298,
#  'Bende': 299,
#  'Ne': 300,
#  'olur': 301,
#  'Hazal Kaya': 302,
#  'Onur Tuna': 303,
#  'Enis Arıkan': 304,
#  'Murat Şenöy': 305,
#  'sıfır': 306,
#  'Savaş Satış': 307,
#  'Onur Akbay': 308,
#  'Hiro Hami': 309,
#  'Kadri Beran Taşkın': 310,
#  'pornografi': 311,
#  'Jean-Pierre Léaud': 312,
#  'Jérémie Renier': 313,
#  'Dominique Blanc': 314,
#  'Bertrand Bonello': 315,
#  'zindan': 316,
#  'ada': 317,
#  'Leonardo DiCaprio': 318,
#  'Ben Kingsley': 319,
#  'Martin Scorsese': 320,
#  'Yıldızlararası': 321,
#  'Matthew McConaughey': 322,
#  'Anne Hathaway': 323,
#  'Michael Caine': 324,
#  'Christopher Nolan': 325,
#  'After': 326,
#  'ayrı': 327,
#  'Josephine Langford': 328,
#  'Hero Fiennes Tiffin': 329,
#  'Louise Lombard': 330,
#  'Castille Landon': 331,
#  'son': 332,
#  'savaş': 333,
#  'Chris Hemsworth': 334,
#  'Charlie': 335,
#  'nin': 336,
#  'çikolata': 337,
#  'Brigitte Millar': 338,
#  'Johnny Depp': 339,
#  'Freddie Highmore': 340,
#  'Tim Burton': 341,
#  'çalıntı': 342,
#  'Bradley Cooper': 343,
#  'Zoe Saldana': 344,
#  'Dennis Quaid': 345,
#  'Brian Klugman': 346,
#  'Lee Sternthal': 347,
#  'Ege Kökenli': 348,
#  'şans': 349,
#  'tanrıça': 350,
#  'Stefano Accorsi': 351,
#  'Edoardo Leo': 352,
#  'Jasmine Trinca': 353,
#  'Ferzan Ozpetek': 354,
#  'Enkanto': 355,
#  'sihir': 356,
#  'Du': 357,
#  'nya': 358,
#  'Byron Howard': 359,
#  'Jared Bush': 360,
#  'iftar': 361,
#  'gazoz': 362,
#  'Cem Yılmaz': 363,
#  'Berat Efe Parlar': 364,
#  'Okan Avcı': 365,
#  'Yüksel Aksu': 366,
#  'Erzurum': 367,
#  'mümessil': 368,
#  'Burak Bozdağ': 369,
#  'Meral Konrat': 370,
#  'Selahattin Taşdöğen': 371,
#  'Servet Aksoy': 372,
#  '4': 373,
#  'kıta': 374,
#  'ayırmak': 375,
#  'Steve Martino': 376,
#  '7': 377,
#  'koğuş': 378,
#  'mucize': 379,
#  'Aras Bulut İynemli': 380,
#  'Nisa Sofiya Aksongur': 381,
#  'Deniz Baysal': 382,
#  'Mehmet Ada Öztekin': 383,
#  'mavi': 384,
#  'en': 385,
#  'sıcak': 386,
#  'renk': 387,
#  'Léa Seydoux': 388,
#  'Adèle Exarchopoulos': 389,
#  'Salim Kechiouche': 390,
#  'Abdellatif Kechiche': 391,
#  'özgürlük': 392,
#  'Eric Johnson': 393,
#  'Malazgirt': 394,
#  '1071': 395,
#  'Cengiz Coşkun': 396,
#  'Vildan Atasever': 397,
#  'Haluk Piyes': 398,
#  'Bilal Kalyoncu': 399,
#  'Özgür Bakar': 400,
#  'şeytan': 401,
#  'kitap': 402,
#  'Engin Yüksel': 403,
#  'Rüya Yürüten': 404,
#  'Cemre Özgül': 405,
#  'Okan Ege Ergüven': 406,
#  'Kocaayak': 407,
#  'Ben Stassen': 408,
#  'Jérémie Degruson': 409,
#  'baba': 410,
#  'Marlon Brando': 411,
#  'Al Pacino': 412,
#  'James Caan': 413,
#  'Francis Ford Coppola': 414,
#  'Ryan Reynolds': 415,
#  'Jodie Comer': 416,
#  'Lil Rel Howery': 417,
#  'Shawn Levy': 418,
#  'Malena': 419,
#  'Monica Bellucci': 420,
#  'Luciano Federico': 421,
#  'Matilde Piana': 422,
#  'Giuseppe Tornatore': 423,
#  'şakir': 424,
#  'korsan': 425,
#  'diyar': 426,
#  'Atilla Şendil': 427,
#  'Levent Ünsal': 428,
#  'Mustafa Oral': 429,
#  'Haluk Can Dizdaroğlu': 430,
#  'Berk Tokay': 431,
#  'Vincent Cassel': 432,
#  'Albert Dupontel': 433,
#  'Gaspar Noé': 434,
#  'top': 435,
#  'Gun': 436,
#  'Maverick': 437,
#  'Tom Cruise': 438,
#  'Miles Teller': 439,
#  'Jennifer Connelly': 440,
#  'Joseph Kosinski': 441,
#  'Paul Walker': 442,
#  'Rob Cohen': 443,
#  'hep': 444,
#  'yek': 445,
#  'belâ': 446,
#  'ok': 447,
#  'Altan': 448,
#  'İnan Ulaş Torun': 449,
#  'Önder Açıkbaş': 450,
#  'Yıldırım Memişoğlu': 451,
#  '4N1K': 452,
#  'düğün': 453,
#  'Gözde Mutluer': 454,
#  'Burak Yörük': 455,
#  'Sina Özer': 456,
#  'Deniz Coşkun': 457,
#  'Hz': 458,
#  'Muhammed': 459,
#  'Allah': 460,
#  'In': 461,
#  'elçi': 462,
#  'Majid Majidi': 463,
#  'Melissa': 464,
#  'P': 465,
#  'María Valverde': 466,
#  'Letizia Ciampa': 467,
#  'Primo Reggiani': 468,
#  'Luca Guadagnino': 469,
#  'Zalo': 470,
#  'Sermiyan Midyat': 471,
#  'Kıvanç Baran Arslan': 472,
#  'Ersel Şibil': 473,
#  'Necati Aslan': 474,
#  'tokyo': 475,
#  'yarmak': 476,
#  'Lucas Black': 477,
#  'Shad Moss': 478,
#  'Brian Tee': 479,
#  'esaret': 480,
#  'bedel': 481,
#  'Tim Robbins': 482,
#  'Morgan Freeman': 483,
#  'Bob Gunton': 484,
#  'Frank Darabont': 485,
#  'piyanist': 486,
#  'Adrien Brody': 487,
#  'Thomas Kretschmann': 488,
#  'Emilia Fox': 489,
#  'Roman Polanski': 490,
#  'Rio': 491,
#  'soygun': 492,
#  'Dwayne Johnson': 493,
#  'istilâ': 494,
#  'Daniel Craig': 495,
#  'Jeremy Northam': 496,
#  'Oliver Hirschbiegel': 497,
#  'İrfan Kangı': 498,
#  'Cem Korkmaz': 499,
#  'Belfast': 500,
#  'Caitriona Balfe': 501,
#  'Jude Hill': 502,
#  'Kenneth Branagh': 503,
#  'Spencer': 504,
#  'Kristen Stewart': 505,
#  'Timothy Spall': 506,
#  'Jack Nielen': 507,
#  'Pablo Larraín': 508,
#  'Tut': 509,
#  'Gael García Bernal': 510,
#  'Vicky Krieps': 511,
#  'Rufus Sewell': 512,
#  'M. Night Shyamalan': 513,
#  'şuur': 514,
#  'Ebru Şahin': 515,
#  'Burcu Kara': 516,
#  'Umut Ertek': 517,
#  'ambulans': 518,
#  'Jake Gyllenhaal': 519,
#  'Yahya Abdul-Mateen II': 520,
#  'Eiza Gonzalez': 521,
#  'Michael Bay': 522,
#  'uzak': 523,
#  'kışkırtmak': 524,
#  'Yuliya Mayarchuk': 525,
#  'Max Parodi': 526,
#  'Francesca Nunzi': 527,
#  'Tinto Brass': 528,
#  'yüzük': 529,
#  'efendi': 530,
#  'kardeş': 531,
#  'Elijah Wood': 532,
#  'Sean Astin': 533,
#  'Ian McKellen': 534,
#  'Peter Jackson': 535,
#  'iki': 536,
#  'Bergüzar Korel': 537,
#  'Engin Akyürek': 538,
#  'İpek Bilgin': 539,
#  'Ali Bilgin': 540,
#  'umut': 541,
#  'kaybetmek': 542,
#  'Thandiwe Newton': 543,
#  'Jaden Smith': 544,
#  'Gabriele Muccino': 545,
#  'alacakaranlık': 546,
#  'Efsane': 547,
#  'Şafak': 548,
#  'bölü': 549,
#  '1': 550,
#  'Taylor Lautner': 551,
#  'Bill Condon': 552,
#  'As': 553,
#  'Hürkuş': 554,
#  'elmas': 555,
#  'H. Sinan Güngör': 556,
#  'Hakan Bol': 557,
#  'bayan': 558,
#  'Peregrine': 559,
#  'inmek': 560,
#  'tuhaf': 561,
#  'çocuk': 562,
#  'Eva Green': 563,
#  'Asa Butterfield': 564,
#  'Samuel L. Jackson': 565,
#  'nefes': 566,
#  'Stephen Lang': 567,
#  'Jane Levy': 568,
#  'Dylan Minnette': 569,
#  'Fede Alvarez': 570,
#  'Moonfall': 571,
#  'Halle Berry': 572,
#  'Patrick Wilson': 573,
#  'John Bradley (II)': 574,
#  'Roland Emmerich': 575,
#  'Anka': 576,
#  'Ozan Akbaba': 577,
#  'Engin Hepileri': 578,
#  'Deniz Işın': 579,
#  'Süleyman Mert Özdemir': 580,
#  'joker': 581,
#  'Joaquin Phoenix': 582,
#  'Robert De Niro': 583,
#  'Zazie Beetz': 584,
#  'Todd Phillips': 585,
#  'bıçaklamak': 586,
#  'çekmek': 587,
#  'Ana de Armas': 588,
#  'Rian Johnson': 589,
#  'kap': 590,
#  'Phillips': 591,
#  'Tom Hanks': 592,
#  'Catherine Keener': 593,
#  'Barkhad Abdi': 594,
#  'Paul Greengrass': 595,
#  'Dünya': 596,
#  'kötü': 597,
#  'İnsa': 598,
#  'Renate Reinsve': 599,
#  'Anders Danielsen Lie': 600,
#  'Herbert Nordrum': 601,
#  'Joachim Trier': 602,
#  'Hababam': 603,
#  'sınıf': 604,
#  'yeniden': 605,
#  'Toygan Avanoğlu': 606,
#  'Hande Katipoğlu': 607,
#  'sayılamak': 608,
#  'Taraji P. Henson': 609,
#  'Octavia Spencer': 610,
#  'Janelle Monáe': 611,
#  'Theodore Melfi': 612,
#  'çapkımak': 613,
#  'Dramatik komedi': 614,
#  'Anne Heche': 615,
#  'Margarita Levieva': 616,
#  'David Mackenzie': 617,
#  'Rafa': 618,
#  'tayf': 619,
#  'Göbeklitepe': 620,
#  'İsmail Fidan': 621,
#  'Catherine Hardwicke': 622,
#  'Delibal': 623,
#  'Çağatay Ulusoy': 624,
#  'Leyla Lydia Tuğutlu': 625,
#  'Hüseyin Avni Danyal': 626,
#  'unutmak': 627,
#  'fısıldamak': 628,
#  'Müzik': 629,
#  'Mehmet Günsür': 630,
#  'Işıl Yücesoy': 631,
#  'Çağan Irmak': 632,
#  'labirent': 633,
#  'ölümcül': 634,
#  'kaçışmak': 635,
#  "Dylan O'Brien": 636,
#  'Aml Ameen': 637,
#  'Will Poulter': 638,
#  'Wes Ball': 639,
#  'parazit': 640,
#  'Song Kang-Ho': 641,
#  'Woo-sik Choi': 642,
#  'Park So-Dam': 643,
#  'Bong Joon Ho': 644,
#  'dağ': 645,
#  'Savaş filmi': 646,
#  'Çağlar Ertuğrul': 647,
#  'Murat Serezli': 648,
#  'Alper Çağlar': 649,
#  'par': 650,
#  'av': 651,
#  'Jonah Hill': 652,
#  'Margot Robbie': 653,
#  'genç': 654,
#  'güzel': 655,
#  'Marine Vacth': 656,
#  'Géraldine Pailhas': 657,
#  'Frédéric Pierrot': 658,
#  'François Ozon': 659,
#  'kafalamak': 660,
#  'karışık': 661,
#  'Atakan Özyurt': 662,
#  'Bilal Hancı': 663,
#  'Fatih Yasin': 664,
#  'Yücel Yolcu': 665,
#  'Luka': 666,
#  'Enrico Casarosa': 667,
#  'Mut': 668,
#  'azınlık': 669,
#  'Marina Foïs': 670,
#  'Nicolas Duvauchelle': 671,
#  'Roschdy Zem': 672,
#  'Antony Cordier': 673,
#  'Uzay': 674,
#  'yolcu': 675,
#  'Jennifer Lawrence': 676,
#  'Chris Pratt': 677,
#  'Michael Sheen': 678,
#  'Morten Tyldum': 679,
#  'afacan': 680,
#  'iş': 681,
#  'baş': 682,
#  'düşmek': 683,
#  'Gürgen Öz': 684,
#  'Burak Hakkı': 685,
#  'Enes Ateş': 686,
#  'tam': 687,
#  'kafadan': 688,
#  'karavan': 689,
#  'Ali Biçim': 690,
#  'Mesut Can Tomay': 691,
#  'Efekan Can': 692,
#  'Oğuz Öztürk': 693,
#  'Celal Öztürk': 694,
#  'sık': 695,
#  'yakalamak': 696,
#  'Christopher Walken': 697,
#  'Steven Spielberg': 698,
#  'inanılmaz': 699,
#  'Andrew Garfield': 700,
#  'Emma Stone': 701,
#  'Rhys Ifans': 702,
#  'incir': 703,
#  'reçel': 704,
#  'Halil Sezai Paracıkoğlu': 705,
#  'Şafak Pekdemir': 706,
#  'Sinan Çalışkanoğlu': 707,
#  'Aytaç Ağırlar': 708,
#  'çıngırak': 709,
#  'Beren Demirkaya': 710,
#  'Tarkan Yılmaz': 711,
#  'Atilla Özdal': 712,
#  'Ralph Waldo': 713,
#  'turnuva': 714,
#  'Taylor Russell McKenzie': 715,
#  'Logan Miller': 716,
#  'Thomas Cocquerel': 717,
#  'Adam Robitel': 718,
#  'arınmak': 719,
#  'gece': 720,
#  'Ethan Hawke': 721,
#  'Lena Headey': 722,
#  'Max Burkholder': 723,
#  'James DeMonaco': 724,
#  'korku': 725,
#  'seans': 726,
#  'Ron Livingston': 727,
#  'James Wan': 728,
#  'Amerika': 729,
#  'Scarlett Johansson': 730,
#  'sekreter': 731,
#  'James Spader': 732,
#  'Maggie Gyllenhaal': 733,
#  'Jeremy Davies': 734,
#  'Steven Shainberg': 735,
#  'patron': 736,
#  'bebek': 737,
#  'şirket': 738,
#  'Tom McGrath': 739,
#  'pasta': 740,
#  'Jason Biggs': 741,
#  'Seann William Scott': 742,
#  'Chris Klein': 743,
#  'Paul Weitz': 744,
#  'Chris Weitz': 745,
#  'How': 746,
#  'It': 747,
#  'Ends': 748,
#  'Theo James': 749,
#  'Forest Whitaker': 750,
#  'Kat Graham': 751,
#  'David M. Rosenthal': 752,
#  'suret': 753,
#  'Bruce Willis': 754,
#  'Radha Mitchell': 755,
#  'Rosamund Pike': 756,
#  'Jonathan Mostow': 757,
#  'büyük': 758,
#  'çarpışmak': 759,
#  'koral': 760,
#  'Henry Selick': 761,
#  'sen': 762,
#  'ban': 763,
#  'Kalan': 764,
#  'Neslihan Atagül': 765,
#  'Ekin Koç': 766,
#  'Zeynep Kankonde': 767,
#  'Abdullah Oğuz': 768,
#  'cennet': 769,
#  'Michael FitzGerald': 770,
#  'Orlando Bloom': 771,
#  'Liam Neeson': 772,
#  'Ridley Scott': 773,
#  'doğru': 774,
#  'Mu': 775,
#  'Cesaret': 776,
#  'mi': 777,
#  'Lucy Hale': 778,
#  'Tyler Posey': 779,
#  'Violett Beane': 780,
#  'Jeff Wadlow': 781,
#  'Michael Keaton': 782,
#  'dövüşmek': 783,
#  'kulüp': 784,
#  'Brad Pitt': 785,
#  'Edward Norton': 786,
#  'Helena Bonham Carter': 787,
#  'David Fincher': 788,
#  'yemek': 789,
#  'Ultron': 790,
#  'çağ': 791,
#  'Joss Whedon': 792,
#  'kızmak': 793,
#  'Ben Affleck': 794,
#  'Neil Patrick Harris': 795,
#  'elti': 796,
#  'Gupse Özay': 797,
#  'Merve Dizdar': 798,
#  'Ferit Aktuğ': 799,
#  'komplo': 800,
#  'Chris Pine': 801,
#  'Ben Foster': 802,
#  'Gillian Jacobs': 803,
#  'Tarik Saleh': 804,
#  'silmek': 805,
#  'Kate Winslet': 806,
#  'Kirsten Dunst': 807,
#  'Michel Gondry': 808,
#  'mezar': 809,
#  'tükürmek': 810,
#  'Sarah Butler': 811,
#  'Chad Lindberg': 812,
#  'Daniel Franzese': 813,
#  'Steven R. Monroe': 814,
#  'Malefiz': 815,
#  'Angelina Jolie': 816,
#  'Elle Fanning': 817,
#  'Sharlto Copley': 818,
#  'Robert Stromberg': 819,
#  'nere': 820,
#  'bulmak': 821,
#  'Katherine Waterston': 822,
#  'Dan Fogler': 823,
#  'minyon': 824,
#  'Gru': 825,
#  'nun': 826,
#  'Kyle Balda': 827,
#  'Azaim': 828,
#  'cin': 829,
#  'Lale Uçak': 830,
#  'İbrahim Şentürk': 831,
#  'Zeynep Sude Tekin': 832,
#  'Erdal Şimşek': 833,
#  'Zodiac': 834,
#  'Anthony Edwards': 835,
#  'Flaşbellek': 836,
#  'Saleh Bakri': 837,
#  'Ali Süleyman': 838,
#  'Sara El Debuch': 839,
#  'Derviş Zaim': 840,
#  'iblis': 841,
#  'Sahib': 842,
#  'Fatih Paşalı': 843,
#  'Sebahat Adalar': 844,
#  'Doğancan Küçükağa': 845,
#  'Berk Aygül': 846,
#  'sevmek': 847,
#  'Gökhan Kıraç': 848,
#  'Zerrin Sümer': 849,
#  'Ender Mıhlar': 850,
#  'Resident': 851,
#  'Evil': 852,
#  'Raccoon': 853,
#  'Kaya Scodelario': 854,
#  'Hannah John-Kamen': 855,
#  'Robbie Amell': 856,
#  'Johannes Roberts': 857,
#  'Tutku': 858,
#  'oyun': 859,
#  'Todd Field': 860,
#  'Predestination': 861,
#  'Sarah Snook': 862,
#  'Noah Taylor': 863,
#  'Michael Spierig': 864,
#  'Peter Spierig': 865,
#  'sosyal': 866,
#  'ağ': 867,
#  'Jesse Eisenberg': 868,
#  'temel': 869,
#  'içgüdü': 870,
#  'Michael Douglas': 871,
#  'Sharon Stone': 872,
#  'Jeanne Tripplehorn': 873,
#  'Paul Verhoeven': 874,
#  'Viggo Mortensen': 875,
#  'celâl': 876,
#  'Ceren': 877,
#  'Ezgi Mola': 878,
#  'Gökcen Gökçebağ': 879,
#  'Jurassic': 880,
#  'World': 881,
#  'Hakimiyet': 882,
#  'Bryce Dallas Howard': 883,
#  'Jeff Goldblum': 884,
#  'Colin Trevorrow': 885,
#  'akıl': 886,
#  'Russell Crowe': 887,
#  'Ed Harris': 888,
#  'Ron Howard': 889,
#  'fetih': 890,
#  '1453': 891,
#  'Devrim Evin': 892,
#  'İbrahim Çelikkol': 893,
#  'Dilek Serbest': 894,
#  'Faruk Aksoy': 895,
#  'Fury': 896,
#  'Shia LaBeouf': 897,
#  'Logan Lerman': 898,
#  'David Ayer': 899,
#  'yukarı': 900,
#  'bakmak': 901,
#  'Bob Peterson': 902,
#  'Pete Docter': 903,
#  'Truman': 904,
#  'Show': 905,
#  'Laura Linney': 906,
#  'Natascha McElhone': 907,
#  'Peter Weir': 908,
#  'Dilek': 909,
#  'İhsan Berk Aydın': 910,
#  'Meta Akkuş': 911,
#  'prestij': 912,
#  'Hugh Jackman': 913,
#  'Christian Bale': 914,
#  'Shang': 915,
#  'Chi': 916,
#  'onmak': 917,
#  'halk': 918,
#  'Simu Liu': 919,
#  'Tony Leung Chiu-Wai': 920,
#  'Awkwafina': 921,
#  'Destin Daniel Cretton': 922,
#  'Tobey Maguire': 923,
#  'James Franco': 924,
#  'Five': 925,
#  'Feet': 926,
#  'aparmak': 927,
#  'Haley Lu Richardson': 928,
#  'Cole Sprouse': 929,
#  'Moises Arias': 930,
#  'Justin Baldoni': 931,
#  'kim': 932,
#  'demek': 933,
#  'diye': 934,
#  'Pierre Perifel': 935,
#  'ihtiyar': 936,
#  'delikanlı': 937,
#  'Min-sik Choi': 938,
#  'Yoo Ji-tae': 939,
#  'Kang Hye-Jeong': 940,
#  'Chan-Wook Park': 941,
#  'ayna': 942,
#  'Kiefer Sutherland': 943,
#  'Paula Patton': 944,
#  'Cameron Boyce': 945,
#  'Alexandre Aja': 946,
#  'Matrix': 947,
#  'Resurrections': 948,
#  'Keanu Reeves': 949,
#  'Carrie-Anne Moss': 950,
#  'Lana Wachowski': 951,
#  'Kingsman': 952,
#  'servis': 953,
#  'Casusluk': 954,
#  'Taron Egerton': 955,
#  'Colin Firth': 956,
#  'Matthew Vaughn': 957,
#  'Karayip': 958,
#  'siyah': 959,
#  'inci': 960,
#  'lanet': 961,
#  'Geoffrey Rush': 962,
#  'Keira Knightley': 963,
#  'Gore Verbinski': 964,
#  'boy': 965,
#  'Striped': 966,
#  'Pyjamas': 967,
#  'David Thewlis': 968,
#  'Mark Herman': 969,
#  'Deborah Ann Woll': 970,
#  'süper': 971,
#  'Don Hall': 972,
#  'Chris Williams (II)': 973,
#  'Lolita': 974,
#  'Jeremy Irons': 975,
#  'Melanie Griffith': 976,
#  'Dominique Swain': 977,
#  'Adrian Lyne': 978,
#  'No': 979,
#  '26': 980,
#  'ölü': 981,
#  'çığlık': 982,
#  'Hande Öğüt': 983,
#  'Barış Baktaş': 984,
#  'Lola Polat': 985,
#  'Batuhan Çelik': 986,
#  'ön': 987,
#  'ben': 988,
#  'Emilia Clarke': 989,
#  'Sam Claflin': 990,
#  'Janet McTeer': 991,
#  'Thea Sharrock': 992,
#  'iç': 993,
#  'yaşamak': 994,
#  'deri': 995,
#  'Antonio Banderas': 996,
#  'Elena Anaya': 997,
#  'Marisa Paredes': 998,
#  'Pedro Almodóvar': 999,
#  ...}

# %%
index2kelime
# Out:
# {0: '<UNK>',
#  1: 'Bergen',
#  2: 'Dram',
#  3: 'Biyografik',
#  4: 'Farah Zeynep Abdullah',
#  5: 'Erdal Beşikçioğlu',
#  6: 'Tilbe Saran',
#  7: 'Mehmet Binay',
#  8: 'Caner Alper',
#  9: 'kirpi',
#  10: 'Sonic',
#  11: '2',
#  12: 'Animasyon',
#  13: 'Aile',
#  14: 'Macera',
#  15: 'Jim Carrey',
#  16: 'James Marsden',
#  17: None,
#  18: 'Jeff Fowler',
#  19: 'fantastik',
#  20: 'canavar',
#  21: 'Dumbledore',
#  22: 'un',
#  23: 'sır',
#  24: 'Fantastik',
#  25: 'Eddie Redmayne',
#  26: 'Jude Law',
#  27: 'Mads Mikkelsen',
#  28: 'David Yates',
#  29: 'Aykut',
#  30: 'enişte',
#  31: 'Komedi',
#  32: 'Cem Gelinoğlu',
#  33: 'Melis Babadağ',
#  34: 'Hakan Yılmaz',
#  35: 'Onur Bilgetay',
#  36: 'Morbius',
#  37: 'Aksiyon',
#  38: 'Jared Leto',
#  39: 'Matt Smith (XI)',
#  40: 'Adria Arjona',
#  41: 'Daniel Espinosa',
#  42: 'kırmız',
#  43: 'Domee Shi',
#  44: 'kar',
#  45: 'Hazar Ergüçlü',
#  46: 'Ozan Uygun',
#  47: 'Halil Babür',
#  48: 'Emre Erdoğdu',
#  49: 'kesişmek',
#  50: 'iyi',
#  51: 'var',
#  52: 'ermek',
#  53: 'İsmail Hacıoğlu',
#  54: 'Rahman Başel',
#  55: 'Alayça Öztürk',
#  56: 'Özer Feyzioğlu',
#  57: 'örümcek',
#  58: 'adam',
#  59: 'ev',
#  60: 'dönmek',
#  61: 'yok',
#  62: 'Tom Holland',
#  63: 'Zendaya',
#  64: 'Benedict Cumberbatch',
#  65: 'Jon Watts',
#  66: 'The',
#  67: 'batmak',
#  68: 'Polisiye',
#  69: 'Gerilim',
#  70: 'Robert Pattinson',
#  71: 'Zoë Kravitz',
#  72: 'Paul Dano',
#  73: 'Matt Reeves',
#  74: 'doktor',
#  75: 'Strange',
#  76: 'çok',
#  77: 'evre',
#  78: 'çılgın',
#  79: 'Elizabeth Olsen',
#  80: 'Rachel McAdams',
#  81: 'Sam Raimi',
#  82: 'Dilberay',
#  83: 'Büşra Pekin',
#  84: 'Zeliha Kendirci',
#  85: 'Nursel Köse',
#  86: 'Ketche',
#  87: 'doru',
#  88: 'macera',
#  89: 'orman',
#  90: 'Arkın Aktaç',
#  91: 'zaman',
#  92: 'karşı',
#  93: 'Bilimkurgu',
#  94: 'Amanda Seyfried',
#  95: 'Justin Timberlake',
#  96: 'Cillian Murphy',
#  97: 'Andrew Niccol',
#  98: 'gri',
#  99: 'el',
#  100: 'ton',
#  101: 'Romantik',
#  102: 'Jamie Dornan',
#  103: 'Dakota Johnson',
#  104: 'Jennifer Ehle',
#  105: 'Sam Taylor-Johnson',
#  106: 'recep',
#  107: 'İvedik',
#  108: '6',
#  109: 'Şahan Gökbakar',
#  110: 'Nurullah Çelebi',
#  111: 'Somer Karvan',
#  112: 'Togan Gökbakar',
#  113: 'karmak',
#  114: 'Erotik',
#  115: 'Bella Heathcote',
#  116: 'James Foley',
#  117: 'Day',
#  118: 'bir',
#  119: 'adamı',
#  120: 'hikâye',
#  121: 'Ufuk Bayraktar',
#  122: 'Gizem Karaca',
#  123: 'Ahmet Varlı',
#  124: 'Uğur Bayraktar',
#  125: 'kayıp',
#  126: 'şehir',
#  127: 'Sandra Bullock',
#  128: 'Channing Tatum',
#  129: 'Daniel Radcliffe',
#  130: 'Aaron Nee',
#  131: 'Adam Nee',
#  132: 'kuzey',
#  133: 'Tarihi',
#  134: 'Alexander Skarsgård',
#  135: 'Nicole Kidman',
#  136: 'Claes Bang',
#  137: 'Robert Eggers',
#  138: 'Dune',
#  139: 'çöl',
#  140: 'gezegen',
#  141: 'Timothée Chalamet',
#  142: 'Rebecca Ferguson',
#  143: 'Oscar Isaac',
#  144: 'Denis Villeneuve',
#  145: 'hız',
#  146: 'öfke',
#  147: '9',
#  148: 'Vin Diesel',
#  149: 'Michelle Rodriguez',
#  150: 'Jordana Brewster',
#  151: 'Justin Lin',
#  152: 'Venom',
#  153: 'zehir',
#  154: 'Tom Hardy',
#  155: 'Woody Harrelson',
#  156: 'Michelle Williams',
#  157: 'Andy Serkis',
#  158: 'gizli',
#  159: 'gerçek',
#  160: 'Korku',
#  161: 'Sarah Paulson',
#  162: 'Kiera Allen',
#  163: 'Pat Healy',
#  164: 'Aneesh Chaganty',
#  165: 'bura',
#  166: 'o',
#  167: 'kalmak',
#  168: 'Cameron Diaz',
#  169: 'Ashton Kutcher',
#  170: 'Lake Bell',
#  171: 'Tom Vaughan',
#  172: 'deha',
#  173: 'Chris Evans',
#  174: 'Mckenna Grace',
#  175: 'Lindsay Duncan',
#  176: 'Marc Webb',
#  177: 'ihanet',
#  178: 'Kristin Scott Thomas',
#  179: 'Sergi López',
#  180: 'Yvan Attal',
#  181: 'Catherine Corsini',
#  182: 'yedinci',
#  183: 'hayat',
#  184: 'Noomi Rapace',
#  185: 'Glenn Close',
#  186: 'Willem Dafoe',
#  187: 'Tommy Wirkola',
#  188: 'buz',
#  189: 'devir',
#  190: '3',
#  191: 'dinozorlar',
#  192: 'şafak',
#  193: 'Carlos Saldanha',
#  194: 'Mike Thurmeier',
#  195: 'her',
#  196: 'şey',
#  197: 'yer',
#  198: 'aynı',
#  199: 'an',
#  200: 'Michelle Yeoh',
#  201: 'Ke Huy Quan',
#  202: 'Jamie Lee Curtis',
#  203: 'Daniel Scheinert',
#  204: 'Daniel Kwan',
#  205: 'ölüm',
#  206: 'aşk',
#  207: 'Blake Lively',
#  208: 'Michiel Huisman',
#  209: 'Harrison Ford',
#  210: 'Lee Toland Krieger',
#  211: 'kadın',
#  212: 'seks',
#  213: 'günlük',
#  214: 'Belén Fabra',
#  215: 'Leonardo Sbaraglia',
#  216: 'Llum Barrera',
#  217: 'Christian Molina',
#  218: 'uçmak',
#  219: 'plan',
#  220: 'Jodie Foster',
#  221: 'Michael Irby',
#  222: 'Assaf Cohen',
#  223: 'Robert Schwentke',
#  224: 'Enes',
#  225: 'batur',
#  226: 'kahraman',
#  227: 'Enes Batur',
#  228: 'Ömer Başdoğan',
#  229: 'Altan Erkekli',
#  230: 'Doğa Can Anafarta',
#  231: 'adamak',
#  232: 'kutsal',
#  233: 'kavga',
#  234: 'İsmail Filiz',
#  235: 'Esra Bilgiç',
#  236: 'Baki İlhan',
#  237: 'Emir Khalilzadeh',
#  238: 'ketenpere',
#  239: 'Şafak Sezer',
#  240: 'Hakan Ural',
#  241: 'Mehmet Esen',
#  242: 'Kamil Çetin',
#  243: 'intikam',
#  244: 'vakit',
#  245: 'Jason Statham',
#  246: 'Holt McCallany',
#  247: 'Josh Hartnett',
#  248: 'Guy Ritchie',
#  249: 'çağrı',
#  250: 'Anthony Quinn',
#  251: 'Irène Papas',
#  252: 'Michael Ansara',
#  253: 'Moustapha Akkad',
#  254: 'Avengers',
#  255: 'Endgame',
#  256: 'Robert Downey Jr.',
#  257: 'Mark Ruffalo',
#  258: 'Joe Russo',
#  259: 'Anthony Russo',
#  260: 'Harry',
#  261: 'Potter',
#  262: 'felsefe',
#  263: 'taşımak',
#  264: 'Rupert Grint',
#  265: 'Emma Watson',
#  266: 'Chris Columbus',
#  267: 'düş',
#  268: 'fabrika',
#  269: 'Kim Hagen Jensen',
#  270: 'düşman',
#  271: 'Vera Farmiga',
#  272: 'Peter Sarsgaard',
#  273: 'Isabelle Fuhrman',
#  274: 'Jaume Collet-Serra',
#  275: 'kök',
#  276: 'Ahu Türkpençe',
#  277: 'Lale Başar',
#  278: 'Savaş Alp Başar',
#  279: 'Deniz Akçay Katıksız',
#  280: 'Uncharted',
#  281: 'Mark Wahlberg',
#  282: 'Sophia Ali',
#  283: 'Ruben Fleischer',
#  284: 'Araf',
#  285: '5',
#  286: 'aile',
#  287: 'Can Suoruç',
#  288: 'Tuğgül Küçükoğlu',
#  289: 'İrem İpek',
#  290: 'Uğur Kaplan',
#  291: 'kral',
#  292: 'Richard',
#  293: 'yükselmek',
#  294: 'şampiyon',
#  295: 'Will Smith',
#  296: 'Aunjanue Ellis',
#  297: 'Saniyya Sidney',
#  298: 'Reinaldo Marcus Green',
#  299: 'Bende',
#  300: 'Ne',
#  301: 'olur',
#  302: 'Hazal Kaya',
#  303: 'Onur Tuna',
#  304: 'Enis Arıkan',
#  305: 'Murat Şenöy',
#  306: 'sıfır',
#  307: 'Savaş Satış',
#  308: 'Onur Akbay',
#  309: 'Hiro Hami',
#  310: 'Kadri Beran Taşkın',
#  311: 'pornografi',
#  312: 'Jean-Pierre Léaud',
#  313: 'Jérémie Renier',
#  314: 'Dominique Blanc',
#  315: 'Bertrand Bonello',
#  316: 'zindan',
#  317: 'ada',
#  318: 'Leonardo DiCaprio',
#  319: 'Ben Kingsley',
#  320: 'Martin Scorsese',
#  321: 'Yıldızlararası',
#  322: 'Matthew McConaughey',
#  323: 'Anne Hathaway',
#  324: 'Michael Caine',
#  325: 'Christopher Nolan',
#  326: 'After',
#  327: 'ayrı',
#  328: 'Josephine Langford',
#  329: 'Hero Fiennes Tiffin',
#  330: 'Louise Lombard',
#  331: 'Castille Landon',
#  332: 'son',
#  333: 'savaş',
#  334: 'Chris Hemsworth',
#  335: 'Charlie',
#  336: 'nin',
#  337: 'çikolata',
#  338: 'Brigitte Millar',
#  339: 'Johnny Depp',
#  340: 'Freddie Highmore',
#  341: 'Tim Burton',
#  342: 'çalıntı',
#  343: 'Bradley Cooper',
#  344: 'Zoe Saldana',
#  345: 'Dennis Quaid',
#  346: 'Brian Klugman',
#  347: 'Lee Sternthal',
#  348: 'Ege Kökenli',
#  349: 'şans',
#  350: 'tanrıça',
#  351: 'Stefano Accorsi',
#  352: 'Edoardo Leo',
#  353: 'Jasmine Trinca',
#  354: 'Ferzan Ozpetek',
#  355: 'Enkanto',
#  356: 'sihir',
#  357: 'Du',
#  358: 'nya',
#  359: 'Byron Howard',
#  360: 'Jared Bush',
#  361: 'iftar',
#  362: 'gazoz',
#  363: 'Cem Yılmaz',
#  364: 'Berat Efe Parlar',
#  365: 'Okan Avcı',
#  366: 'Yüksel Aksu',
#  367: 'Erzurum',
#  368: 'mümessil',
#  369: 'Burak Bozdağ',
#  370: 'Meral Konrat',
#  371: 'Selahattin Taşdöğen',
#  372: 'Servet Aksoy',
#  373: '4',
#  374: 'kıta',
#  375: 'ayırmak',
#  376: 'Steve Martino',
#  377: '7',
#  378: 'koğuş',
#  379: 'mucize',
#  380: 'Aras Bulut İynemli',
#  381: 'Nisa Sofiya Aksongur',
#  382: 'Deniz Baysal',
#  383: 'Mehmet Ada Öztekin',
#  384: 'mavi',
#  385: 'en',
#  386: 'sıcak',
#  387: 'renk',
#  388: 'Léa Seydoux',
#  389: 'Adèle Exarchopoulos',
#  390: 'Salim Kechiouche',
#  391: 'Abdellatif Kechiche',
#  392: 'özgürlük',
#  393: 'Eric Johnson',
#  394: 'Malazgirt',
#  395: '1071',
#  396: 'Cengiz Coşkun',
#  397: 'Vildan Atasever',
#  398: 'Haluk Piyes',
#  399: 'Bilal Kalyoncu',
#  400: 'Özgür Bakar',
#  401: 'şeytan',
#  402: 'kitap',
#  403: 'Engin Yüksel',
#  404: 'Rüya Yürüten',
#  405: 'Cemre Özgül',
#  406: 'Okan Ege Ergüven',
#  407: 'Kocaayak',
#  408: 'Ben Stassen',
#  409: 'Jérémie Degruson',
#  410: 'baba',
#  411: 'Marlon Brando',
#  412: 'Al Pacino',
#  413: 'James Caan',
#  414: 'Francis Ford Coppola',
#  415: 'Ryan Reynolds',
#  416: 'Jodie Comer',
#  417: 'Lil Rel Howery',
#  418: 'Shawn Levy',
#  419: 'Malena',
#  420: 'Monica Bellucci',
#  421: 'Luciano Federico',
#  422: 'Matilde Piana',
#  423: 'Giuseppe Tornatore',
#  424: 'şakir',
#  425: 'korsan',
#  426: 'diyar',
#  427: 'Atilla Şendil',
#  428: 'Levent Ünsal',
#  429: 'Mustafa Oral',
#  430: 'Haluk Can Dizdaroğlu',
#  431: 'Berk Tokay',
#  432: 'Vincent Cassel',
#  433: 'Albert Dupontel',
#  434: 'Gaspar Noé',
#  435: 'top',
#  436: 'Gun',
#  437: 'Maverick',
#  438: 'Tom Cruise',
#  439: 'Miles Teller',
#  440: 'Jennifer Connelly',
#  441: 'Joseph Kosinski',
#  442: 'Paul Walker',
#  443: 'Rob Cohen',
#  444: 'hep',
#  445: 'yek',
#  446: 'belâ',
#  447: 'ok',
#  448: 'Altan',
#  449: 'İnan Ulaş Torun',
#  450: 'Önder Açıkbaş',
#  451: 'Yıldırım Memişoğlu',
#  452: '4N1K',
#  453: 'düğün',
#  454: 'Gözde Mutluer',
#  455: 'Burak Yörük',
#  456: 'Sina Özer',
#  457: 'Deniz Coşkun',
#  458: 'Hz',
#  459: 'Muhammed',
#  460: 'Allah',
#  461: 'In',
#  462: 'elçi',
#  463: 'Majid Majidi',
#  464: 'Melissa',
#  465: 'P',
#  466: 'María Valverde',
#  467: 'Letizia Ciampa',
#  468: 'Primo Reggiani',
#  469: 'Luca Guadagnino',
#  470: 'Zalo',
#  471: 'Sermiyan Midyat',
#  472: 'Kıvanç Baran Arslan',
#  473: 'Ersel Şibil',
#  474: 'Necati Aslan',
#  475: 'tokyo',
#  476: 'yarmak',
#  477: 'Lucas Black',
#  478: 'Shad Moss',
#  479: 'Brian Tee',
#  480: 'esaret',
#  481: 'bedel',
#  482: 'Tim Robbins',
#  483: 'Morgan Freeman',
#  484: 'Bob Gunton',
#  485: 'Frank Darabont',
#  486: 'piyanist',
#  487: 'Adrien Brody',
#  488: 'Thomas Kretschmann',
#  489: 'Emilia Fox',
#  490: 'Roman Polanski',
#  491: 'Rio',
#  492: 'soygun',
#  493: 'Dwayne Johnson',
#  494: 'istilâ',
#  495: 'Daniel Craig',
#  496: 'Jeremy Northam',
#  497: 'Oliver Hirschbiegel',
#  498: 'İrfan Kangı',
#  499: 'Cem Korkmaz',
#  500: 'Belfast',
#  501: 'Caitriona Balfe',
#  502: 'Jude Hill',
#  503: 'Kenneth Branagh',
#  504: 'Spencer',
#  505: 'Kristen Stewart',
#  506: 'Timothy Spall',
#  507: 'Jack Nielen',
#  508: 'Pablo Larraín',
#  509: 'Tut',
#  510: 'Gael García Bernal',
#  511: 'Vicky Krieps',
#  512: 'Rufus Sewell',
#  513: 'M. Night Shyamalan',
#  514: 'şuur',
#  515: 'Ebru Şahin',
#  516: 'Burcu Kara',
#  517: 'Umut Ertek',
#  518: 'ambulans',
#  519: 'Jake Gyllenhaal',
#  520: 'Yahya Abdul-Mateen II',
#  521: 'Eiza Gonzalez',
#  522: 'Michael Bay',
#  523: 'uzak',
#  524: 'kışkırtmak',
#  525: 'Yuliya Mayarchuk',
#  526: 'Max Parodi',
#  527: 'Francesca Nunzi',
#  528: 'Tinto Brass',
#  529: 'yüzük',
#  530: 'efendi',
#  531: 'kardeş',
#  532: 'Elijah Wood',
#  533: 'Sean Astin',
#  534: 'Ian McKellen',
#  535: 'Peter Jackson',
#  536: 'iki',
#  537: 'Bergüzar Korel',
#  538: 'Engin Akyürek',
#  539: 'İpek Bilgin',
#  540: 'Ali Bilgin',
#  541: 'umut',
#  542: 'kaybetmek',
#  543: 'Thandiwe Newton',
#  544: 'Jaden Smith',
#  545: 'Gabriele Muccino',
#  546: 'alacakaranlık',
#  547: 'Efsane',
#  548: 'Şafak',
#  549: 'bölü',
#  550: '1',
#  551: 'Taylor Lautner',
#  552: 'Bill Condon',
#  553: 'As',
#  554: 'Hürkuş',
#  555: 'elmas',
#  556: 'H. Sinan Güngör',
#  557: 'Hakan Bol',
#  558: 'bayan',
#  559: 'Peregrine',
#  560: 'inmek',
#  561: 'tuhaf',
#  562: 'çocuk',
#  563: 'Eva Green',
#  564: 'Asa Butterfield',
#  565: 'Samuel L. Jackson',
#  566: 'nefes',
#  567: 'Stephen Lang',
#  568: 'Jane Levy',
#  569: 'Dylan Minnette',
#  570: 'Fede Alvarez',
#  571: 'Moonfall',
#  572: 'Halle Berry',
#  573: 'Patrick Wilson',
#  574: 'John Bradley (II)',
#  575: 'Roland Emmerich',
#  576: 'Anka',
#  577: 'Ozan Akbaba',
#  578: 'Engin Hepileri',
#  579: 'Deniz Işın',
#  580: 'Süleyman Mert Özdemir',
#  581: 'joker',
#  582: 'Joaquin Phoenix',
#  583: 'Robert De Niro',
#  584: 'Zazie Beetz',
#  585: 'Todd Phillips',
#  586: 'bıçaklamak',
#  587: 'çekmek',
#  588: 'Ana de Armas',
#  589: 'Rian Johnson',
#  590: 'kap',
#  591: 'Phillips',
#  592: 'Tom Hanks',
#  593: 'Catherine Keener',
#  594: 'Barkhad Abdi',
#  595: 'Paul Greengrass',
#  596: 'Dünya',
#  597: 'kötü',
#  598: 'İnsa',
#  599: 'Renate Reinsve',
#  600: 'Anders Danielsen Lie',
#  601: 'Herbert Nordrum',
#  602: 'Joachim Trier',
#  603: 'Hababam',
#  604: 'sınıf',
#  605: 'yeniden',
#  606: 'Toygan Avanoğlu',
#  607: 'Hande Katipoğlu',
#  608: 'sayılamak',
#  609: 'Taraji P. Henson',
#  610: 'Octavia Spencer',
#  611: 'Janelle Monáe',
#  612: 'Theodore Melfi',
#  613: 'çapkımak',
#  614: 'Dramatik komedi',
#  615: 'Anne Heche',
#  616: 'Margarita Levieva',
#  617: 'David Mackenzie',
#  618: 'Rafa',
#  619: 'tayf',
#  620: 'Göbeklitepe',
#  621: 'İsmail Fidan',
#  622: 'Catherine Hardwicke',
#  623: 'Delibal',
#  624: 'Çağatay Ulusoy',
#  625: 'Leyla Lydia Tuğutlu',
#  626: 'Hüseyin Avni Danyal',
#  627: 'unutmak',
#  628: 'fısıldamak',
#  629: 'Müzik',
#  630: 'Mehmet Günsür',
#  631: 'Işıl Yücesoy',
#  632: 'Çağan Irmak',
#  633: 'labirent',
#  634: 'ölümcül',
#  635: 'kaçışmak',
#  636: "Dylan O'Brien",
#  637: 'Aml Ameen',
#  638: 'Will Poulter',
#  639: 'Wes Ball',
#  640: 'parazit',
#  641: 'Song Kang-Ho',
#  642: 'Woo-sik Choi',
#  643: 'Park So-Dam',
#  644: 'Bong Joon Ho',
#  645: 'dağ',
#  646: 'Savaş filmi',
#  647: 'Çağlar Ertuğrul',
#  648: 'Murat Serezli',
#  649: 'Alper Çağlar',
#  650: 'par',
#  651: 'av',
#  652: 'Jonah Hill',
#  653: 'Margot Robbie',
#  654: 'genç',
#  655: 'güzel',
#  656: 'Marine Vacth',
#  657: 'Géraldine Pailhas',
#  658: 'Frédéric Pierrot',
#  659: 'François Ozon',
#  660: 'kafalamak',
#  661: 'karışık',
#  662: 'Atakan Özyurt',
#  663: 'Bilal Hancı',
#  664: 'Fatih Yasin',
#  665: 'Yücel Yolcu',
#  666: 'Luka',
#  667: 'Enrico Casarosa',
#  668: 'Mut',
#  669: 'azınlık',
#  670: 'Marina Foïs',
#  671: 'Nicolas Duvauchelle',
#  672: 'Roschdy Zem',
#  673: 'Antony Cordier',
#  674: 'Uzay',
#  675: 'yolcu',
#  676: 'Jennifer Lawrence',
#  677: 'Chris Pratt',
#  678: 'Michael Sheen',
#  679: 'Morten Tyldum',
#  680: 'afacan',
#  681: 'iş',
#  682: 'baş',
#  683: 'düşmek',
#  684: 'Gürgen Öz',
#  685: 'Burak Hakkı',
#  686: 'Enes Ateş',
#  687: 'tam',
#  688: 'kafadan',
#  689: 'karavan',
#  690: 'Ali Biçim',
#  691: 'Mesut Can Tomay',
#  692: 'Efekan Can',
#  693: 'Oğuz Öztürk',
#  694: 'Celal Öztürk',
#  695: 'sık',
#  696: 'yakalamak',
#  697: 'Christopher Walken',
#  698: 'Steven Spielberg',
#  699: 'inanılmaz',
#  700: 'Andrew Garfield',
#  701: 'Emma Stone',
#  702: 'Rhys Ifans',
#  703: 'incir',
#  704: 'reçel',
#  705: 'Halil Sezai Paracıkoğlu',
#  706: 'Şafak Pekdemir',
#  707: 'Sinan Çalışkanoğlu',
#  708: 'Aytaç Ağırlar',
#  709: 'çıngırak',
#  710: 'Beren Demirkaya',
#  711: 'Tarkan Yılmaz',
#  712: 'Atilla Özdal',
#  713: 'Ralph Waldo',
#  714: 'turnuva',
#  715: 'Taylor Russell McKenzie',
#  716: 'Logan Miller',
#  717: 'Thomas Cocquerel',
#  718: 'Adam Robitel',
#  719: 'arınmak',
#  720: 'gece',
#  721: 'Ethan Hawke',
#  722: 'Lena Headey',
#  723: 'Max Burkholder',
#  724: 'James DeMonaco',
#  725: 'korku',
#  726: 'seans',
#  727: 'Ron Livingston',
#  728: 'James Wan',
#  729: 'Amerika',
#  730: 'Scarlett Johansson',
#  731: 'sekreter',
#  732: 'James Spader',
#  733: 'Maggie Gyllenhaal',
#  734: 'Jeremy Davies',
#  735: 'Steven Shainberg',
#  736: 'patron',
#  737: 'bebek',
#  738: 'şirket',
#  739: 'Tom McGrath',
#  740: 'pasta',
#  741: 'Jason Biggs',
#  742: 'Seann William Scott',
#  743: 'Chris Klein',
#  744: 'Paul Weitz',
#  745: 'Chris Weitz',
#  746: 'How',
#  747: 'It',
#  748: 'Ends',
#  749: 'Theo James',
#  750: 'Forest Whitaker',
#  751: 'Kat Graham',
#  752: 'David M. Rosenthal',
#  753: 'suret',
#  754: 'Bruce Willis',
#  755: 'Radha Mitchell',
#  756: 'Rosamund Pike',
#  757: 'Jonathan Mostow',
#  758: 'büyük',
#  759: 'çarpışmak',
#  760: 'koral',
#  761: 'Henry Selick',
#  762: 'sen',
#  763: 'ban',
#  764: 'Kalan',
#  765: 'Neslihan Atagül',
#  766: 'Ekin Koç',
#  767: 'Zeynep Kankonde',
#  768: 'Abdullah Oğuz',
#  769: 'cennet',
#  770: 'Michael FitzGerald',
#  771: 'Orlando Bloom',
#  772: 'Liam Neeson',
#  773: 'Ridley Scott',
#  774: 'doğru',
#  775: 'Mu',
#  776: 'Cesaret',
#  777: 'mi',
#  778: 'Lucy Hale',
#  779: 'Tyler Posey',
#  780: 'Violett Beane',
#  781: 'Jeff Wadlow',
#  782: 'Michael Keaton',
#  783: 'dövüşmek',
#  784: 'kulüp',
#  785: 'Brad Pitt',
#  786: 'Edward Norton',
#  787: 'Helena Bonham Carter',
#  788: 'David Fincher',
#  789: 'yemek',
#  790: 'Ultron',
#  791: 'çağ',
#  792: 'Joss Whedon',
#  793: 'kızmak',
#  794: 'Ben Affleck',
#  795: 'Neil Patrick Harris',
#  796: 'elti',
#  797: 'Gupse Özay',
#  798: 'Merve Dizdar',
#  799: 'Ferit Aktuğ',
#  800: 'komplo',
#  801: 'Chris Pine',
#  802: 'Ben Foster',
#  803: 'Gillian Jacobs',
#  804: 'Tarik Saleh',
#  805: 'silmek',
#  806: 'Kate Winslet',
#  807: 'Kirsten Dunst',
#  808: 'Michel Gondry',
#  809: 'mezar',
#  810: 'tükürmek',
#  811: 'Sarah Butler',
#  812: 'Chad Lindberg',
#  813: 'Daniel Franzese',
#  814: 'Steven R. Monroe',
#  815: 'Malefiz',
#  816: 'Angelina Jolie',
#  817: 'Elle Fanning',
#  818: 'Sharlto Copley',
#  819: 'Robert Stromberg',
#  820: 'nere',
#  821: 'bulmak',
#  822: 'Katherine Waterston',
#  823: 'Dan Fogler',
#  824: 'minyon',
#  825: 'Gru',
#  826: 'nun',
#  827: 'Kyle Balda',
#  828: 'Azaim',
#  829: 'cin',
#  830: 'Lale Uçak',
#  831: 'İbrahim Şentürk',
#  832: 'Zeynep Sude Tekin',
#  833: 'Erdal Şimşek',
#  834: 'Zodiac',
#  835: 'Anthony Edwards',
#  836: 'Flaşbellek',
#  837: 'Saleh Bakri',
#  838: 'Ali Süleyman',
#  839: 'Sara El Debuch',
#  840: 'Derviş Zaim',
#  841: 'iblis',
#  842: 'Sahib',
#  843: 'Fatih Paşalı',
#  844: 'Sebahat Adalar',
#  845: 'Doğancan Küçükağa',
#  846: 'Berk Aygül',
#  847: 'sevmek',
#  848: 'Gökhan Kıraç',
#  849: 'Zerrin Sümer',
#  850: 'Ender Mıhlar',
#  851: 'Resident',
#  852: 'Evil',
#  853: 'Raccoon',
#  854: 'Kaya Scodelario',
#  855: 'Hannah John-Kamen',
#  856: 'Robbie Amell',
#  857: 'Johannes Roberts',
#  858: 'Tutku',
#  859: 'oyun',
#  860: 'Todd Field',
#  861: 'Predestination',
#  862: 'Sarah Snook',
#  863: 'Noah Taylor',
#  864: 'Michael Spierig',
#  865: 'Peter Spierig',
#  866: 'sosyal',
#  867: 'ağ',
#  868: 'Jesse Eisenberg',
#  869: 'temel',
#  870: 'içgüdü',
#  871: 'Michael Douglas',
#  872: 'Sharon Stone',
#  873: 'Jeanne Tripplehorn',
#  874: 'Paul Verhoeven',
#  875: 'Viggo Mortensen',
#  876: 'celâl',
#  877: 'Ceren',
#  878: 'Ezgi Mola',
#  879: 'Gökcen Gökçebağ',
#  880: 'Jurassic',
#  881: 'World',
#  882: 'Hakimiyet',
#  883: 'Bryce Dallas Howard',
#  884: 'Jeff Goldblum',
#  885: 'Colin Trevorrow',
#  886: 'akıl',
#  887: 'Russell Crowe',
#  888: 'Ed Harris',
#  889: 'Ron Howard',
#  890: 'fetih',
#  891: '1453',
#  892: 'Devrim Evin',
#  893: 'İbrahim Çelikkol',
#  894: 'Dilek Serbest',
#  895: 'Faruk Aksoy',
#  896: 'Fury',
#  897: 'Shia LaBeouf',
#  898: 'Logan Lerman',
#  899: 'David Ayer',
#  900: 'yukarı',
#  901: 'bakmak',
#  902: 'Bob Peterson',
#  903: 'Pete Docter',
#  904: 'Truman',
#  905: 'Show',
#  906: 'Laura Linney',
#  907: 'Natascha McElhone',
#  908: 'Peter Weir',
#  909: 'Dilek',
#  910: 'İhsan Berk Aydın',
#  911: 'Meta Akkuş',
#  912: 'prestij',
#  913: 'Hugh Jackman',
#  914: 'Christian Bale',
#  915: 'Shang',
#  916: 'Chi',
#  917: 'onmak',
#  918: 'halk',
#  919: 'Simu Liu',
#  920: 'Tony Leung Chiu-Wai',
#  921: 'Awkwafina',
#  922: 'Destin Daniel Cretton',
#  923: 'Tobey Maguire',
#  924: 'James Franco',
#  925: 'Five',
#  926: 'Feet',
#  927: 'aparmak',
#  928: 'Haley Lu Richardson',
#  929: 'Cole Sprouse',
#  930: 'Moises Arias',
#  931: 'Justin Baldoni',
#  932: 'kim',
#  933: 'demek',
#  934: 'diye',
#  935: 'Pierre Perifel',
#  936: 'ihtiyar',
#  937: 'delikanlı',
#  938: 'Min-sik Choi',
#  939: 'Yoo Ji-tae',
#  940: 'Kang Hye-Jeong',
#  941: 'Chan-Wook Park',
#  942: 'ayna',
#  943: 'Kiefer Sutherland',
#  944: 'Paula Patton',
#  945: 'Cameron Boyce',
#  946: 'Alexandre Aja',
#  947: 'Matrix',
#  948: 'Resurrections',
#  949: 'Keanu Reeves',
#  950: 'Carrie-Anne Moss',
#  951: 'Lana Wachowski',
#  952: 'Kingsman',
#  953: 'servis',
#  954: 'Casusluk',
#  955: 'Taron Egerton',
#  956: 'Colin Firth',
#  957: 'Matthew Vaughn',
#  958: 'Karayip',
#  959: 'siyah',
#  960: 'inci',
#  961: 'lanet',
#  962: 'Geoffrey Rush',
#  963: 'Keira Knightley',
#  964: 'Gore Verbinski',
#  965: 'boy',
#  966: 'Striped',
#  967: 'Pyjamas',
#  968: 'David Thewlis',
#  969: 'Mark Herman',
#  970: 'Deborah Ann Woll',
#  971: 'süper',
#  972: 'Don Hall',
#  973: 'Chris Williams (II)',
#  974: 'Lolita',
#  975: 'Jeremy Irons',
#  976: 'Melanie Griffith',
#  977: 'Dominique Swain',
#  978: 'Adrian Lyne',
#  979: 'No',
#  980: '26',
#  981: 'ölü',
#  982: 'çığlık',
#  983: 'Hande Öğüt',
#  984: 'Barış Baktaş',
#  985: 'Lola Polat',
#  986: 'Batuhan Çelik',
#  987: 'ön',
#  988: 'ben',
#  989: 'Emilia Clarke',
#  990: 'Sam Claflin',
#  991: 'Janet McTeer',
#  992: 'Thea Sharrock',
#  993: 'iç',
#  994: 'yaşamak',
#  995: 'deri',
#  996: 'Antonio Banderas',
#  997: 'Elena Anaya',
#  998: 'Marisa Paredes',
#  999: 'Pedro Almodóvar',
#  ...}

# %%
len(kelime2index)
# Out:
# 12633

# %%
import numpy as np

# %%
doc_mat = np.zeros((len(df), len(kelime2index)))

# %%
for i, doc in enumerate(clean_col.values):
    for token in doc:
        token_index = kelime2index[token]
        doc_mat[i][token_index] += 1

# %%
doc_mat[0]
# Out:
# array([0., 1., 1., ..., 0., 0., 0.])

# %%
def cos_sim(v1, v2):
    return np.dot(v1, v2) / (np.linalg.norm(v1) * np.linalg.norm(v2))

# %%
# sorgular
random.seed(42) # otostopçunun galaksi rehberi
film_indexi = random.randrange(len(df))
film = df.iloc[film_indexi]
film["film adi"], film["ozet ve detaylar"], film["tur"]
# Out:
# ('Gridiron Gang',
#  'Reşit olmamış gençlerin kaldığı bir tutukevinde kamp yöneticisi olan Sean Porter, gençlere futbol sayesinde takım olabilme bilinci ve kendilerine güven duygusu aşılamaya çalışır. Phil Joanou yönetimindeki filmde, Akrep Kral ve The Rundown filmlerinden tanıdık The Rock başrolde.',
#  "['Dramatik komedi']")

# %%
benzerlikler = []
sorgu_film = doc_mat[film_indexi]
for vec in doc_mat:
    benzerlik = cos_sim(sorgu_film, vec)
    benzerlikler.append(benzerlik)

# %%
test_list = [1, 5, 4, 2]
print(np.array(test_list).argsort()[:2])
print((- np.array(test_list)).argsort()[:2])
# Out:
# [0 3]
# [1 2]

# %%
# en yakın 5 film
top5_film_indexleri = (- np.array(benzerlikler)).argsort()[:5]

# %%
for i in top5_film_indexleri:
    film = df.iloc[i]
    print(film["film adi"], film["ozet ve detaylar"], film["tur"])
    print(" - " * 20)
# Out:
# Gridiron Gang Reşit olmamış gençlerin kaldığı bir tutukevinde kamp yöneticisi olan Sean Porter, gençlere futbol sayesinde takım olabilme bilinci ve kendilerine güven duygusu aşılamaya çalışır. Phil Joanou yönetimindeki filmde, Akrep Kral ve The Rundown filmlerinden tanıdık The Rock başrolde. ['Dramatik komedi']
#  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -
# Aşkopat Aşkopat, yetimanede yetişmiş olan üç sıkı arkadaşın öyküsünü perdeye taşıyor. Emre, Salih ve Duman isimli bu üç sıkı dost, yetimhaneden kaçınca hayatları da hızla değişmeye başlar. Yetimhaneden beraber ayrıldıkları zamandan beri aralarındaki bağı hiç bir şartta koparmayan bu üç sıkı dost, yaptıkları yasa dışı işler nedeniyle enselenince soluğu mahkeme salonunda alırlar. Aşırı iyi niyetli ve saf olan Emre yaptıkları bütün yasa ışı işleri mahkemede tek tek anlatınca üç kafadar birer yıl hapis cezasına çarptırılır. Üç kafadar hapisten çıktıktan sonra artık yasa dışı işler yapmayacaklarına dair söz verdikten sonra farklı işler için kolları sıvarlar. Ne var ki girdikleri her işi ellerine yüzlerine bulaştırmaları da uzun sürmez. Üçlünün hayatı, Hadise isimli bir kız ile tanışmalarıyla birlikte hızlı bir şekilde değişmeye başlar.Başrolleri Yıldız Asyalı, Doğuş, Kral'dan tanıdığımız Afrikalı Ali ve tiyatrocu Teoman Gelmez'in paylaştığı Aşkkopat, dramla çevrili bir romantik komedi örneği. ['Dramatik komedi']
#  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -
# Propaganda 1948 yılında yaşanan gerçek bir olaydan konusunu alan film, Sinan Çetin’in en ses getiren yapımları arasında. Film, siyasi otoritenin emriyle bir tel örgüsüyle ikiye bölünen bir köyün bu sınırla birlikte sosyal, duygusal ve manevi olarak da ikiye bölünmesinin ardından yaşanan dokunaklı hikayeyi anlatıyor. Başta gümrük memuru Mehdi ve çocukluk arkadaşı Rahim olmak üzere, birbirleriyle yıllardır birarada yaşayan köy halkı aradaki sınır yüzünden dostlarını, aşklarını ve hayata duydukları inancı yitirirken siyasi ve politik oyunların parçaladığı hayatlar bir kez daha gözler önüne seriliyor. ['Dramatik komedi']
#  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -
# Tıkanma Sex bağımlısı olan ve her türlü işte çalışan Victor Mancini, Alzheimer hastası olan annesinin hastane faturasını ödemek için çeşitli dümenler çevirir. Pahalı lokantalarda boğazına bir şey kaçmış numarası yapar ve onu kurtaran kişilere minnet borcu duyduğunu söyleyip yakasını bırakmaz. Böylece bu insanları maddi olarak sömürmeye başlar.Kült film Fight Club’ın kitabının yazarı Chuck Palahniuk’ın bir başka kitabından sinemaya uyarlanan film, yine adından çok söz ettireceğe benziyor. ['Dramatik komedi']
#  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -
# Muhbir Üniversite öğrencisi genç oğlu, yanlış bir suçlamayla uyuşturucu satıcılığından 20 yıl hapis cezası alınca, düzenli ve sakin bir aile hayatı süren babasının yapacak tek bir şeyi alır: polisle iş birliği yaparak kılık değiştirecek ve uyuşturucu çetesinin en tepesindeki adama ulaşmaya çalışacaktır. Kendi hayatını da riske attığı için eşiyle arası bozulacak olsa da, oğlunu hapiste çürütmeye hiç niyeti yoktur. Fakat kendilerine karşı polisle işbirliği yaptığı örgüt, azımsanmayacak kadar tehlikeli adamlardan oluşmaktadır. John oğlunu kurtarmanın yanı sıra hayatta kalma mücadelesi de verecektir..Filmin yönetmenliğini Ric Roman Waugh üstlenirken senaryo da Waugh ile birlikte Justin Haythe'nin imzası var. Aksiyon türündeki filmin oyuncu kadrosunda ise Dwayne Johnson, Susan Sarandon, Jon Bernthal gibi isimler yer alıyor. ['Aksiyon']
#  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -

# %%
def print_film(row_index):
    film = df.iloc[row_index]
    adi = film['film adi']
    turu = ", ".join(ast.literal_eval(film['tur']))
    ozet = film['ozet ve detaylar']
    if len(ozet) > 150:
        ozet = ozet[:150] + "..."

    print(f"Film adı: {adi} \nTürü: {turu} \nÖzeti: {ozet}")

# %%
def benzerlerini_bul(film_adi, benzer_film_sayisi):
    film_indexi = df[df["film adi"] == film_adi].index[0]
    print("Aranan Film:")
    print_film(film_indexi)
    print(" * " * 20)
    print(" * " * 20)

    benzerlikler = []
    sorgu_film = doc_mat[film_indexi]
    for vec in doc_mat:
        benzerlik = cos_sim(sorgu_film, vec)
        benzerlikler.append(benzerlik)
    
    en_benzer_film_indexleri = (- np.array(benzerlikler)).argsort()[:benzer_film_sayisi + 1]
    print("Benzer Filmler:\n")
    for i in en_benzer_film_indexleri[1:]:
        print_film(i)
        print(" - " * 20)
        print(" - " * 20)

# %%
benzerlerini_bul("Kirpi Sonic 2", 3)
# Out:
# Aranan Film:
# Film adı: Kirpi Sonic 2
# Türü: Animasyon, Aile, Macera
# Özeti: Çocuk filmi
#
#
# Kirpi Sonic filminin devam halkası olan yapımda, insan biçiminde bir kirpi olan Sonic'in atıldığı maceralar konu ediliyor. Green Hills’...
#  *  *  *  *  *  *  *  *  *  *  *  *  *  *  *  *  *  *  *  *
#  *  *  *  *  *  *  *  *  *  *  *  *  *  *  *  *  *  *  *  *
# Benzer Filmler:
#
# Film adı: Kirpi Sonic
# Türü: Macera, Aile
# Özeti: 6 yaş ve üzeri çocuklar için uygun film
#
#
#
# Kirpi Sonic, peşine düşen yetkililerden kurtulup, şeytani doktorun elinde bulunan yüzükleri geri almaya çal...
#  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -
#  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -
# Film adı: Orman Çocuğu 2
# Türü: Animasyon, Macera, Aile
# Özeti: Disney’in 1967 klasiği Man Cub Mowgli’si, animasyon filmi ile geri dönüyor. Mowgli, şimdi bir orman kasabasında, kendisini evlat edinen bir aile birli...
#  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -
#  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -
# Film adı: İnanılmaz Aile 2
# Türü: Animasyon, Aile, Macera
# Özeti: Çocuk filmi
#
#
# İnanılmaz Aile 2, süper güçlere sahip olan bir ailenin atıldığı maceraları konu ediyor. Süper güçlere sahip aile suçla savaşmaya devam ...
#  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -
#  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -

# %% [markdown]
# İyileştirme için neler yapılabilir? (diğer sütunlar? sütun ağırlıkları?)

# %%
df.head()
# Out:
#                                       film adi  \
# 0                                       Bergen
# 1                                Kirpi Sonic 2
# 2  Fantastik Canavarlar: Dumbledore'un Sırları
# 3                               Aykut Enişte 2
# 4                                      Morbius
#
#                                     ozet ve detaylar  \
# 0  Arabeskin unutulmayan kadın seslerinden biri o...
# 1  Çocuk filmi \n\n\nKirpi Sonic filminin devam h...
# 2  Karanlık büyücü Gellert Grindelwald, büyücülük...
# 3  Aykut Enişte 2, sevdiği kadınla evlilik arifes...
# 4  Morbius, hastalığına deva bulmaya çalışırken b...
#
#                                   tur  \
# 0              ['Dram', 'Biyografik']
# 1     ['Animasyon', 'Aile', 'Macera']
# 2             ['Fantastik', 'Macera']
# 3                          ['Komedi']
# 4  ['Aksiyon', 'Fantastik', 'Macera']
#
#                                            oyuncular  \
# 0  ['Farah Zeynep Abdullah', 'Erdal Beşikçioğlu',...
# 1              ['Jim Carrey', 'James Marsden', None]
# 2   ['Eddie Redmayne', 'Jude Law', 'Mads Mikkelsen']
# 3  ['Cem Gelinoğlu', 'Melis Babadağ', 'Hakan Yılm...
# 4  ['Jared Leto', 'Matt Smith (XI)', 'Adria Arjona']
#
#                           yonetmen  vizyon tarihi     sure  \
# 0  ['Mehmet Binay', 'Caner Alper']    4 Mart 2022  2s 26dk
# 1                  ['Jeff Fowler']   8 Nisan 2022   2s 2dk
# 2                  ['David Yates']  15 Nisan 2022  2s 22dk
# 3                ['Onur Bilgetay']  3 Aralık 2021  1s 55dk
# 4              ['Daniel Espinosa']   1 Nisan 2022  1s 45dk
#
#                                                clean
# 0  [Bergen, Dram, Biyografik, Farah Zeynep Abdull...
# 1  [kirpi, Sonic, 2, Animasyon, Aile, Macera, Jim...
# 2  [fantastik, canavar, Dumbledore, un, sır, Fant...
# 3  [Aykut, enişte, 2, Komedi, Cem Gelinoğlu, Meli...
# 4  [Morbius, Aksiyon, Fantastik, Macera, Jared Le...
